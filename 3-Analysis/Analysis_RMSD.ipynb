# %%
from __future__ import print_function

from collections import OrderedDict

import os
import sys
import glob
from itertools import cycle

import numpy as np
import pandas as pd

from scipy.optimize import curve_fit

from os.path import join

import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

import seaborn as sns
sns.set()

from os.path import join

print("Python version:\n{}\n".format(sys.version))
print("matplotlib version: {}".format(matplotlib.__version__))
print("pandas version: {}".format(pd.__version__))
print("numpy version: {}".format(np.__version__))
print("seaborn version: {}".format(sns.__version__))
# Out:
# Python version:
# 2.7.14 | packaged by conda-forge | (default, Dec  9 2017, 16:18:43)
# [GCC 4.8.2 20140120 (Red Hat 4.8.2-15)]
#
# matplotlib version: 2.1.1
# pandas version: 0.22.0
# numpy version: 1.12.1
# seaborn version: 0.8.1

# %%
sns.set(context='paper', style='whitegrid', palette=sns.color_palette("deep"), font='sans-serif',\
        font_scale=1.6, rc={'grid.linestyle': '--'})

# %%
df1 = pd.read_csv("closed_rmsd_to_closed.dat", sep=r'\s+', skiprows=1, names=['time (ns)', 'RMSD1'])
df2 = pd.read_csv("closed_rmsd_to_open.dat", sep=r'\s+', skiprows=1, names=['time (ns)', 'RMSD2'])
df3 = pd.read_csv("open_rmsd_to_closed.dat", sep=r'\s+', skiprows=1, names=['time (ns)', 'RMSD1'])
df4 = pd.read_csv("open_rmsd_to_open.dat", sep=r'\s+', skiprows=1, names=['time (ns)', 'RMSD2'])

# %%
df1['RMSD2']=df2['RMSD2']
df1['State']="Closed"
df3['RMSD2']=df4['RMSD2']
df3['State']="Open"

# %%
df_all=pd.concat([df1,df3])
df_all= df_all.drop(['time (ns)'], axis=1)
df_all
# Out:
#         RMSD1   RMSD2   State
# 0      1.1135  3.0703  Closed
# 1      1.0591  3.0482  Closed
# 2      1.0825  3.1266  Closed
# 3      1.0713  2.9878  Closed
# 4      1.0782  2.9886  Closed
# 5      1.1921  2.9779  Closed
# 6      1.1777  2.9638  Closed
# 7      1.4447  2.7404  Closed
# 8      1.2687  2.9794  Closed
# 9      1.1978  3.1453  Closed
# 10     1.1778  3.0058  Closed
# 11     1.1896  3.0115  Closed
# 12     1.2107  2.9840  Closed
# 13     1.2040  3.1128  Closed
# 14     1.2112  3.1578  Closed
# 15     1.1524  3.0469  Closed
# 16     1.1515  3.0301  Closed
# 17     1.1475  3.0370  Closed
# 18     1.0728  3.0861  Closed
# 19     1.1773  2.9074  Closed
# 20     1.1365  2.9511  Closed
# 21     1.1017  3.0677  Closed
# 22     1.2642  3.2854  Closed
# 23     1.2694  3.1520  Closed
# 24     1.2757  3.2188  Closed
# 25     1.3178  3.1528  Closed
# 26     1.3291  3.0344  Closed
# 27     1.4069  3.1295  Closed
# 28     1.4718  3.0483  Closed
# 29     1.4108  3.1347  Closed
# ...       ...     ...     ...
# 99970  3.0866  2.1819    Open
# 99971  3.0518  2.0742    Open
# 99972  2.9347  1.9471    Open
# 99973  2.9360  1.9416    Open
# 99974  2.9488  2.0292    Open
# 99975  2.8705  1.8912    Open
# 99976  2.8596  1.9062    Open
# 99977  2.9820  2.0102    Open
# 99978  3.1818  2.0173    Open
# 99979  3.0752  2.1206    Open
# 99980  3.0415  1.9863    Open
# 99981  2.9115  2.0025    Open
# 99982  3.0189  2.1030    Open
# 99983  3.1508  2.0738    Open
# 99984  3.2276  2.0530    Open
# 99985  3.0034  2.0871    Open
# 99986  3.0293  2.1590    Open
# 99987  3.0180  1.9948    Open
# 99988  2.9169  2.0714    Open
# 99989  3.0604  2.2244    Open
# 99990  2.9718  1.9895    Open
# 99991  3.0003  2.0915    Open
# 99992  2.7841  2.1203    Open
# 99993  2.9072  2.0281    Open
# 99994  2.8219  1.9466    Open
# 99995  2.7353  2.1859    Open
# 99996  2.8354  2.0099    Open
# 99997  2.9660  2.1168    Open
# 99998  2.6940  1.9643    Open
# 99999  2.9556  2.0490    Open
#
# [198891 rows x 3 columns]

# %%
sns.set(context='paper', style='whitegrid', palette=sns.color_palette("deep"), font='sans-serif',\
        font_scale=1.6, rc={'grid.linestyle': '--'})

fig, axes = plt.subplots(1)

df_all.groupby("State").plot(x="RMSD1", y='RMSD2', ax=axes, marker=".", ms=2, ls='None')
start, stop = axes.get_xlim()
loc = plticker.MultipleLocator(base=0.5)
axes.xaxis.set_major_locator(loc)
#axes.set_aspect('equal')
axes.set_xlabel(r'RMSD to closed ($\AA$)')
axes.set_ylabel(r'RMSD to open ($\AA$)')
axes.set(xlim=(0,6) , ylim=(0, 4))
axes.legend_.remove()
plt.savefig('./RMSD.pdf')
plt.savefig('./RMSD.png')
plt.show()

# %%
fig, axes = plt.subplots(1)

df1.plot(x="RMSD1", y='RMSD2', ax=axes, marker=".", ms=2, ls='None')
#grid.add_legend();
start, stop = axes.get_xlim()
loc = plticker.MultipleLocator(base=0.5)
axes.xaxis.set_major_locator(loc)
axes.set_aspect('equal')
axes.set_xlabel(r'RMSD to closed ($\AA$)')
axes.set_ylabel(r'RMSD to open ($\AA$)')
#axes.set(xlim=(10,14) , ylim=(0, 4))
axes.legend_.remove()
plt.savefig('./RMSD1.pdf')
#plt.savefig('./twist7.png')
plt.show()

# %%
fig, axes = plt.subplots(1)

df3.plot(x="RMSD1", y='RMSD2', ax=axes, marker=".", ms=2, ls='None')
#grid.add_legend();
start, stop = axes.get_xlim()
loc = plticker.MultipleLocator(base=0.5)
axes.xaxis.set_major_locator(loc)
axes.set_aspect('equal')
axes.set_xlabel(r'RMSD to closed ($\AA$)')
axes.set_ylabel(r'RMSD to open ($\AA$)')
#axes.set(xlim=(0,4) , ylim=(10, 14))
axes.legend_.remove()
plt.savefig('./RMSD2.pdf')
#plt.savefig('./twist7.png')
plt.show()
