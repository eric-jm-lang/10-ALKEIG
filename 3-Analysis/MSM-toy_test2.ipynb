# %%
# %matplotlib ipympl
from matplotlib import pylab as plt
import matplotlib
import molpx

import os
import sys
import glob
from itertools import cycle

import numpy as np
import pandas as pd

from os.path import join

import seaborn as sns

import mdtraj as md
import scipy.cluster.hierarchy
from scipy.spatial.distance import squareform

import pyemma

import random

from os.path import join

from collections import OrderedDict
from collections import defaultdict


print("Python version:\n{}\n".format(sys.version))
print("matplotlib version: {}".format(matplotlib.__version__))
print("pandas version: {}".format(pd.__version__))
print("numpy version: {}".format(np.__version__))
print("seaborn version: {}".format(sns.__version__))
# Out:
# Python version:
# 3.6.5 |Anaconda custom (64-bit)| (default, Apr 29 2018, 16:14:56)
# [GCC 7.2.0]
#
# matplotlib version: 2.2.2
# pandas version: 0.23.0
# numpy version: 1.12.1
# seaborn version: 0.8.1

# %%
topfile = './Trajectories/open10_dry.parm7'
from glob import glob
trajfile = 'toy_traj.nc'

# %%
ref1 = md.load('./Trajectories/closed10_dry.rst7', top='./Trajectories/closed10_dry.parm7')
ref2 = md.load('./Trajectories/open10_dry.rst7', top='./Trajectories/open10_dry.parm7')

# %%
feat = pyemma.coordinates.featurizer(topfile)
feat.add_distances_ca()
feat.describe()
# Out:
# ['DIST: GLY 1 CA 8 - GLY 4 CA 49',
#  'DIST: GLY 1 CA 8 - GLN 5 CA 56',
#  'DIST: GLY 1 CA 8 - ALA 6 CA 73',
#  'DIST: GLY 1 CA 8 - LEU 7 CA 83',
#  'DIST: GLY 1 CA 8 - LYS 8 CA 102',
#  'DIST: GLY 1 CA 8 - GLU 9 CA 124',
#  'DIST: GLY 1 CA 8 - ILE 10 CA 139',
#  'DIST: GLY 1 CA 8 - GLY 11 CA 158',
#  'DIST: GLY 1 CA 8 - LYS 12 CA 165',
#  'DIST: GLY 1 CA 8 - ALA 13 CA 187',
#  'DIST: GLY 1 CA 8 - LEU 14 CA 197',
#  'DIST: GLY 1 CA 8 - LYS 15 CA 216',
#  'DIST: GLY 1 CA 8 - GLU 16 CA 238',
#  'DIST: GLY 1 CA 8 - ILE 17 CA 253',
#  'DIST: GLY 1 CA 8 - GLY 18 CA 272',
#  'DIST: GLY 1 CA 8 - TYR 19 CA 279',
#  'DIST: GLY 1 CA 8 - ALA 20 CA 300',
#  'DIST: GLY 1 CA 8 - LEU 21 CA 310',
#  'DIST: GLY 1 CA 8 - LYS 22 CA 329',
#  'DIST: GLY 1 CA 8 - GLU 23 CA 351',
#  'DIST: GLY 1 CA 8 - ILE 24 CA 366',
#  'DIST: GLY 1 CA 8 - GLY 25 CA 385',
#  'DIST: GLY 1 CA 8 - GLN 26 CA 392',
#  'DIST: GLY 1 CA 8 - ALA 27 CA 409',
#  'DIST: GLY 1 CA 8 - LEU 28 CA 419',
#  'DIST: GLY 1 CA 8 - LYS 29 CA 438',
#  'DIST: GLY 1 CA 8 - GLY 30 CA 460',
#  'DIST: GLY 1 CA 8 - GLY 33 CA 476',
#  'DIST: GLY 1 CA 8 - GLU 34 CA 483',
#  'DIST: GLY 1 CA 8 - ILE 35 CA 498',
#  'DIST: GLY 1 CA 8 - GLY 36 CA 517',
#  'DIST: GLY 1 CA 8 - GLN 37 CA 524',
#  'DIST: GLY 1 CA 8 - ALA 38 CA 541',
#  'DIST: GLY 1 CA 8 - LEU 39 CA 551',
#  'DIST: GLY 1 CA 8 - LYS 40 CA 570',
#  'DIST: GLY 1 CA 8 - GLU 41 CA 592',
#  'DIST: GLY 1 CA 8 - ILE 42 CA 607',
#  'DIST: GLY 1 CA 8 - GLY 43 CA 626',
#  'DIST: GLY 1 CA 8 - LYS 44 CA 633',
#  'DIST: GLY 1 CA 8 - ALA 45 CA 655',
#  'DIST: GLY 1 CA 8 - LEU 46 CA 665',
#  'DIST: GLY 1 CA 8 - LYS 47 CA 684',
#  'DIST: GLY 1 CA 8 - GLU 48 CA 706',
#  'DIST: GLY 1 CA 8 - ILE 49 CA 721',
#  'DIST: GLY 1 CA 8 - GLY 50 CA 740',
#  'DIST: GLY 1 CA 8 - TYR 51 CA 747',
#  'DIST: GLY 1 CA 8 - ALA 52 CA 768',
#  'DIST: GLY 1 CA 8 - LEU 53 CA 778',
#  'DIST: GLY 1 CA 8 - LYS 54 CA 797',
#  'DIST: GLY 1 CA 8 - GLU 55 CA 819',
#  'DIST: GLY 1 CA 8 - ILE 56 CA 834',
#  'DIST: GLY 1 CA 8 - GLY 57 CA 853',
#  'DIST: GLY 1 CA 8 - GLN 58 CA 860',
#  'DIST: GLY 1 CA 8 - ALA 59 CA 877',
#  'DIST: GLY 1 CA 8 - LEU 60 CA 887',
#  'DIST: GLY 1 CA 8 - LYS 61 CA 906',
#  'DIST: GLY 1 CA 8 - GLY 62 CA 928',
#  'DIST: GLY 1 CA 8 - GLY 65 CA 944',
#  'DIST: GLY 1 CA 8 - GLU 66 CA 951',
#  'DIST: GLY 1 CA 8 - ILE 67 CA 966',
#  'DIST: GLY 1 CA 8 - GLY 68 CA 985',
#  'DIST: GLY 1 CA 8 - GLN 69 CA 992',
#  'DIST: GLY 1 CA 8 - ALA 70 CA 1009',
#  'DIST: GLY 1 CA 8 - LEU 71 CA 1019',
#  'DIST: GLY 1 CA 8 - LYS 72 CA 1038',
#  'DIST: GLY 1 CA 8 - GLU 73 CA 1060',
#  'DIST: GLY 1 CA 8 - ILE 74 CA 1075',
#  'DIST: GLY 1 CA 8 - GLY 75 CA 1094',
#  'DIST: GLY 1 CA 8 - LYS 76 CA 1101',
#  'DIST: GLY 1 CA 8 - ALA 77 CA 1123',
#  'DIST: GLY 1 CA 8 - LEU 78 CA 1133',
#  'DIST: GLY 1 CA 8 - LYS 79 CA 1152',
#  'DIST: GLY 1 CA 8 - GLU 80 CA 1174',
#  'DIST: GLY 1 CA 8 - ILE 81 CA 1189',
#  'DIST: GLY 1 CA 8 - GLY 82 CA 1208',
#  'DIST: GLY 1 CA 8 - TYR 83 CA 1215',
#  'DIST: GLY 1 CA 8 - ALA 84 CA 1236',
#  'DIST: GLY 1 CA 8 - LEU 85 CA 1246',
#  'DIST: GLY 1 CA 8 - LYS 86 CA 1265',
#  'DIST: GLY 1 CA 8 - GLU 87 CA 1287',
#  'DIST: GLY 1 CA 8 - ILE 88 CA 1302',
#  'DIST: GLY 1 CA 8 - GLY 89 CA 1321',
#  'DIST: GLY 1 CA 8 - GLN 90 CA 1328',
#  'DIST: GLY 1 CA 8 - ALA 91 CA 1345',
#  'DIST: GLY 1 CA 8 - LEU 92 CA 1355',
#  'DIST: GLY 1 CA 8 - LYS 93 CA 1374',
#  'DIST: GLY 1 CA 8 - GLY 94 CA 1396',
#  'DIST: GLY 1 CA 8 - GLY 97 CA 1412',
#  'DIST: GLY 1 CA 8 - GLU 98 CA 1419',
#  'DIST: GLY 1 CA 8 - ILE 99 CA 1434',
#  'DIST: GLY 1 CA 8 - GLY 100 CA 1453',
#  'DIST: GLY 1 CA 8 - GLN 101 CA 1460',
#  'DIST: GLY 1 CA 8 - ALA 102 CA 1477',
#  'DIST: GLY 1 CA 8 - LEU 103 CA 1487',
#  'DIST: GLY 1 CA 8 - LYS 104 CA 1506',
#  'DIST: GLY 1 CA 8 - GLU 105 CA 1528',
#  'DIST: GLY 1 CA 8 - ILE 106 CA 1543',
#  'DIST: GLY 1 CA 8 - GLY 107 CA 1562',
#  'DIST: GLY 1 CA 8 - LYS 108 CA 1569',
#  'DIST: GLY 1 CA 8 - ALA 109 CA 1591',
#  'DIST: GLY 1 CA 8 - LEU 110 CA 1601',
#  'DIST: GLY 1 CA 8 - LYS 111 CA 1620',
#  'DIST: GLY 1 CA 8 - GLU 112 CA 1642',
#  'DIST: GLY 1 CA 8 - ILE 113 CA 1657',
#  'DIST: GLY 1 CA 8 - GLY 114 CA 1676',
#  'DIST: GLY 1 CA 8 - TYR 115 CA 1683',
#  'DIST: GLY 1 CA 8 - ALA 116 CA 1704',
#  'DIST: GLY 1 CA 8 - LEU 117 CA 1714',
#  'DIST: GLY 1 CA 8 - LYS 118 CA 1733',
#  'DIST: GLY 1 CA 8 - GLU 119 CA 1755',
#  'DIST: GLY 1 CA 8 - ILE 120 CA 1770',
#  'DIST: GLY 1 CA 8 - GLY 121 CA 1789',
#  'DIST: GLY 1 CA 8 - GLN 122 CA 1796',
#  'DIST: GLY 1 CA 8 - ALA 123 CA 1813',
#  'DIST: GLY 1 CA 8 - LEU 124 CA 1823',
#  'DIST: GLY 1 CA 8 - LYS 125 CA 1842',
#  'DIST: GLY 1 CA 8 - GLY 126 CA 1864',
#  'DIST: GLY 1 CA 8 - GLY 129 CA 1880',
#  'DIST: GLY 1 CA 8 - GLU 130 CA 1887',
#  'DIST: GLY 1 CA 8 - ILE 131 CA 1902',
#  'DIST: GLY 1 CA 8 - GLY 132 CA 1921',
#  'DIST: GLY 1 CA 8 - GLN 133 CA 1928',
#  'DIST: GLY 1 CA 8 - ALA 134 CA 1945',
#  'DIST: GLY 1 CA 8 - LEU 135 CA 1955',
#  'DIST: GLY 1 CA 8 - LYS 136 CA 1974',
#  'DIST: GLY 1 CA 8 - GLU 137 CA 1996',
#  'DIST: GLY 1 CA 8 - ILE 138 CA 2011',
#  'DIST: GLY 1 CA 8 - GLY 139 CA 2030',
#  'DIST: GLY 1 CA 8 - LYS 140 CA 2037',
#  'DIST: GLY 1 CA 8 - ALA 141 CA 2059',
#  'DIST: GLY 1 CA 8 - LEU 142 CA 2069',
#  'DIST: GLY 1 CA 8 - LYS 143 CA 2088',
#  'DIST: GLY 1 CA 8 - GLU 144 CA 2110',
#  'DIST: GLY 1 CA 8 - ILE 145 CA 2125',
#  'DIST: GLY 1 CA 8 - GLY 146 CA 2144',
#  'DIST: GLY 1 CA 8 - TYR 147 CA 2151',
#  'DIST: GLY 1 CA 8 - ALA 148 CA 2172',
#  'DIST: GLY 1 CA 8 - LEU 149 CA 2182',
#  'DIST: GLY 1 CA 8 - LYS 150 CA 2201',
#  'DIST: GLY 1 CA 8 - GLU 151 CA 2223',
#  'DIST: GLY 1 CA 8 - ILE 152 CA 2238',
#  'DIST: GLY 1 CA 8 - GLY 153 CA 2257',
#  'DIST: GLY 1 CA 8 - GLN 154 CA 2264',
#  'DIST: GLY 1 CA 8 - ALA 155 CA 2281',
#  'DIST: GLY 1 CA 8 - LEU 156 CA 2291',
#  'DIST: GLY 1 CA 8 - LYS 157 CA 2310',
#  'DIST: GLY 1 CA 8 - GLY 158 CA 2332',
#  'DIST: GLY 1 CA 8 - GLY 161 CA 2348',
#  'DIST: GLY 1 CA 8 - GLU 162 CA 2355',
#  'DIST: GLY 1 CA 8 - ILE 163 CA 2370',
#  'DIST: GLY 1 CA 8 - GLY 164 CA 2389',
#  'DIST: GLY 1 CA 8 - GLN 165 CA 2396',
#  'DIST: GLY 1 CA 8 - ALA 166 CA 2413',
#  'DIST: GLY 1 CA 8 - LEU 167 CA 2423',
#  'DIST: GLY 1 CA 8 - LYS 168 CA 2442',
#  'DIST: GLY 1 CA 8 - GLU 169 CA 2464',
#  'DIST: GLY 1 CA 8 - ILE 170 CA 2479',
#  'DIST: GLY 1 CA 8 - GLY 171 CA 2498',
#  'DIST: GLY 1 CA 8 - LYS 172 CA 2505',
#  'DIST: GLY 1 CA 8 - ALA 173 CA 2527',
#  'DIST: GLY 1 CA 8 - LEU 174 CA 2537',
#  'DIST: GLY 1 CA 8 - LYS 175 CA 2556',
#  'DIST: GLY 1 CA 8 - GLU 176 CA 2578',
#  'DIST: GLY 1 CA 8 - ILE 177 CA 2593',
#  'DIST: GLY 1 CA 8 - GLY 178 CA 2612',
#  'DIST: GLY 1 CA 8 - TYR 179 CA 2619',
#  'DIST: GLY 1 CA 8 - ALA 180 CA 2640',
#  'DIST: GLY 1 CA 8 - LEU 181 CA 2650',
#  'DIST: GLY 1 CA 8 - LYS 182 CA 2669',
#  'DIST: GLY 1 CA 8 - GLU 183 CA 2691',
#  'DIST: GLY 1 CA 8 - ILE 184 CA 2706',
#  'DIST: GLY 1 CA 8 - GLY 185 CA 2725',
#  'DIST: GLY 1 CA 8 - GLN 186 CA 2732',
#  'DIST: GLY 1 CA 8 - ALA 187 CA 2749',
#  'DIST: GLY 1 CA 8 - LEU 188 CA 2759',
#  'DIST: GLY 1 CA 8 - LYS 189 CA 2778',
#  'DIST: GLY 1 CA 8 - GLY 190 CA 2800',
#  'DIST: GLU 2 CA 15 - GLN 5 CA 56',
#  'DIST: GLU 2 CA 15 - ALA 6 CA 73',
#  'DIST: GLU 2 CA 15 - LEU 7 CA 83',
#  'DIST: GLU 2 CA 15 - LYS 8 CA 102',
#  'DIST: GLU 2 CA 15 - GLU 9 CA 124',
#  'DIST: GLU 2 CA 15 - ILE 10 CA 139',
#  'DIST: GLU 2 CA 15 - GLY 11 CA 158',
#  'DIST: GLU 2 CA 15 - LYS 12 CA 165',
#  'DIST: GLU 2 CA 15 - ALA 13 CA 187',
#  'DIST: GLU 2 CA 15 - LEU 14 CA 197',
#  'DIST: GLU 2 CA 15 - LYS 15 CA 216',
#  'DIST: GLU 2 CA 15 - GLU 16 CA 238',
#  'DIST: GLU 2 CA 15 - ILE 17 CA 253',
#  'DIST: GLU 2 CA 15 - GLY 18 CA 272',
#  'DIST: GLU 2 CA 15 - TYR 19 CA 279',
#  'DIST: GLU 2 CA 15 - ALA 20 CA 300',
#  'DIST: GLU 2 CA 15 - LEU 21 CA 310',
#  'DIST: GLU 2 CA 15 - LYS 22 CA 329',
#  'DIST: GLU 2 CA 15 - GLU 23 CA 351',
#  'DIST: GLU 2 CA 15 - ILE 24 CA 366',
#  'DIST: GLU 2 CA 15 - GLY 25 CA 385',
#  'DIST: GLU 2 CA 15 - GLN 26 CA 392',
#  'DIST: GLU 2 CA 15 - ALA 27 CA 409',
#  'DIST: GLU 2 CA 15 - LEU 28 CA 419',
#  'DIST: GLU 2 CA 15 - LYS 29 CA 438',
#  'DIST: GLU 2 CA 15 - GLY 30 CA 460',
#  'DIST: GLU 2 CA 15 - GLY 33 CA 476',
#  'DIST: GLU 2 CA 15 - GLU 34 CA 483',
#  'DIST: GLU 2 CA 15 - ILE 35 CA 498',
#  'DIST: GLU 2 CA 15 - GLY 36 CA 517',
#  'DIST: GLU 2 CA 15 - GLN 37 CA 524',
#  'DIST: GLU 2 CA 15 - ALA 38 CA 541',
#  'DIST: GLU 2 CA 15 - LEU 39 CA 551',
#  'DIST: GLU 2 CA 15 - LYS 40 CA 570',
#  'DIST: GLU 2 CA 15 - GLU 41 CA 592',
#  'DIST: GLU 2 CA 15 - ILE 42 CA 607',
#  'DIST: GLU 2 CA 15 - GLY 43 CA 626',
#  'DIST: GLU 2 CA 15 - LYS 44 CA 633',
#  'DIST: GLU 2 CA 15 - ALA 45 CA 655',
#  'DIST: GLU 2 CA 15 - LEU 46 CA 665',
#  'DIST: GLU 2 CA 15 - LYS 47 CA 684',
#  'DIST: GLU 2 CA 15 - GLU 48 CA 706',
#  'DIST: GLU 2 CA 15 - ILE 49 CA 721',
#  'DIST: GLU 2 CA 15 - GLY 50 CA 740',
#  'DIST: GLU 2 CA 15 - TYR 51 CA 747',
#  'DIST: GLU 2 CA 15 - ALA 52 CA 768',
#  'DIST: GLU 2 CA 15 - LEU 53 CA 778',
#  'DIST: GLU 2 CA 15 - LYS 54 CA 797',
#  'DIST: GLU 2 CA 15 - GLU 55 CA 819',
#  'DIST: GLU 2 CA 15 - ILE 56 CA 834',
#  'DIST: GLU 2 CA 15 - GLY 57 CA 853',
#  'DIST: GLU 2 CA 15 - GLN 58 CA 860',
#  'DIST: GLU 2 CA 15 - ALA 59 CA 877',
#  'DIST: GLU 2 CA 15 - LEU 60 CA 887',
#  'DIST: GLU 2 CA 15 - LYS 61 CA 906',
#  'DIST: GLU 2 CA 15 - GLY 62 CA 928',
#  'DIST: GLU 2 CA 15 - GLY 65 CA 944',
#  'DIST: GLU 2 CA 15 - GLU 66 CA 951',
#  'DIST: GLU 2 CA 15 - ILE 67 CA 966',
#  'DIST: GLU 2 CA 15 - GLY 68 CA 985',
#  'DIST: GLU 2 CA 15 - GLN 69 CA 992',
#  'DIST: GLU 2 CA 15 - ALA 70 CA 1009',
#  'DIST: GLU 2 CA 15 - LEU 71 CA 1019',
#  'DIST: GLU 2 CA 15 - LYS 72 CA 1038',
#  'DIST: GLU 2 CA 15 - GLU 73 CA 1060',
#  'DIST: GLU 2 CA 15 - ILE 74 CA 1075',
#  'DIST: GLU 2 CA 15 - GLY 75 CA 1094',
#  'DIST: GLU 2 CA 15 - LYS 76 CA 1101',
#  'DIST: GLU 2 CA 15 - ALA 77 CA 1123',
#  'DIST: GLU 2 CA 15 - LEU 78 CA 1133',
#  'DIST: GLU 2 CA 15 - LYS 79 CA 1152',
#  'DIST: GLU 2 CA 15 - GLU 80 CA 1174',
#  'DIST: GLU 2 CA 15 - ILE 81 CA 1189',
#  'DIST: GLU 2 CA 15 - GLY 82 CA 1208',
#  'DIST: GLU 2 CA 15 - TYR 83 CA 1215',
#  'DIST: GLU 2 CA 15 - ALA 84 CA 1236',
#  'DIST: GLU 2 CA 15 - LEU 85 CA 1246',
#  'DIST: GLU 2 CA 15 - LYS 86 CA 1265',
#  'DIST: GLU 2 CA 15 - GLU 87 CA 1287',
#  'DIST: GLU 2 CA 15 - ILE 88 CA 1302',
#  'DIST: GLU 2 CA 15 - GLY 89 CA 1321',
#  'DIST: GLU 2 CA 15 - GLN 90 CA 1328',
#  'DIST: GLU 2 CA 15 - ALA 91 CA 1345',
#  'DIST: GLU 2 CA 15 - LEU 92 CA 1355',
#  'DIST: GLU 2 CA 15 - LYS 93 CA 1374',
#  'DIST: GLU 2 CA 15 - GLY 94 CA 1396',
#  'DIST: GLU 2 CA 15 - GLY 97 CA 1412',
#  'DIST: GLU 2 CA 15 - GLU 98 CA 1419',
#  'DIST: GLU 2 CA 15 - ILE 99 CA 1434',
#  'DIST: GLU 2 CA 15 - GLY 100 CA 1453',
#  'DIST: GLU 2 CA 15 - GLN 101 CA 1460',
#  'DIST: GLU 2 CA 15 - ALA 102 CA 1477',
#  'DIST: GLU 2 CA 15 - LEU 103 CA 1487',
#  'DIST: GLU 2 CA 15 - LYS 104 CA 1506',
#  'DIST: GLU 2 CA 15 - GLU 105 CA 1528',
#  'DIST: GLU 2 CA 15 - ILE 106 CA 1543',
#  'DIST: GLU 2 CA 15 - GLY 107 CA 1562',
#  'DIST: GLU 2 CA 15 - LYS 108 CA 1569',
#  'DIST: GLU 2 CA 15 - ALA 109 CA 1591',
#  'DIST: GLU 2 CA 15 - LEU 110 CA 1601',
#  'DIST: GLU 2 CA 15 - LYS 111 CA 1620',
#  'DIST: GLU 2 CA 15 - GLU 112 CA 1642',
#  'DIST: GLU 2 CA 15 - ILE 113 CA 1657',
#  'DIST: GLU 2 CA 15 - GLY 114 CA 1676',
#  'DIST: GLU 2 CA 15 - TYR 115 CA 1683',
#  'DIST: GLU 2 CA 15 - ALA 116 CA 1704',
#  'DIST: GLU 2 CA 15 - LEU 117 CA 1714',
#  'DIST: GLU 2 CA 15 - LYS 118 CA 1733',
#  'DIST: GLU 2 CA 15 - GLU 119 CA 1755',
#  'DIST: GLU 2 CA 15 - ILE 120 CA 1770',
#  'DIST: GLU 2 CA 15 - GLY 121 CA 1789',
#  'DIST: GLU 2 CA 15 - GLN 122 CA 1796',
#  'DIST: GLU 2 CA 15 - ALA 123 CA 1813',
#  'DIST: GLU 2 CA 15 - LEU 124 CA 1823',
#  'DIST: GLU 2 CA 15 - LYS 125 CA 1842',
#  'DIST: GLU 2 CA 15 - GLY 126 CA 1864',
#  'DIST: GLU 2 CA 15 - GLY 129 CA 1880',
#  'DIST: GLU 2 CA 15 - GLU 130 CA 1887',
#  'DIST: GLU 2 CA 15 - ILE 131 CA 1902',
#  'DIST: GLU 2 CA 15 - GLY 132 CA 1921',
#  'DIST: GLU 2 CA 15 - GLN 133 CA 1928',
#  'DIST: GLU 2 CA 15 - ALA 134 CA 1945',
#  'DIST: GLU 2 CA 15 - LEU 135 CA 1955',
#  'DIST: GLU 2 CA 15 - LYS 136 CA 1974',
#  'DIST: GLU 2 CA 15 - GLU 137 CA 1996',
#  'DIST: GLU 2 CA 15 - ILE 138 CA 2011',
#  'DIST: GLU 2 CA 15 - GLY 139 CA 2030',
#  'DIST: GLU 2 CA 15 - LYS 140 CA 2037',
#  'DIST: GLU 2 CA 15 - ALA 141 CA 2059',
#  'DIST: GLU 2 CA 15 - LEU 142 CA 2069',
#  'DIST: GLU 2 CA 15 - LYS 143 CA 2088',
#  'DIST: GLU 2 CA 15 - GLU 144 CA 2110',
#  'DIST: GLU 2 CA 15 - ILE 145 CA 2125',
#  'DIST: GLU 2 CA 15 - GLY 146 CA 2144',
#  'DIST: GLU 2 CA 15 - TYR 147 CA 2151',
#  'DIST: GLU 2 CA 15 - ALA 148 CA 2172',
#  'DIST: GLU 2 CA 15 - LEU 149 CA 2182',
#  'DIST: GLU 2 CA 15 - LYS 150 CA 2201',
#  'DIST: GLU 2 CA 15 - GLU 151 CA 2223',
#  'DIST: GLU 2 CA 15 - ILE 152 CA 2238',
#  'DIST: GLU 2 CA 15 - GLY 153 CA 2257',
#  'DIST: GLU 2 CA 15 - GLN 154 CA 2264',
#  'DIST: GLU 2 CA 15 - ALA 155 CA 2281',
#  'DIST: GLU 2 CA 15 - LEU 156 CA 2291',
#  'DIST: GLU 2 CA 15 - LYS 157 CA 2310',
#  'DIST: GLU 2 CA 15 - GLY 158 CA 2332',
#  'DIST: GLU 2 CA 15 - GLY 161 CA 2348',
#  'DIST: GLU 2 CA 15 - GLU 162 CA 2355',
#  'DIST: GLU 2 CA 15 - ILE 163 CA 2370',
#  'DIST: GLU 2 CA 15 - GLY 164 CA 2389',
#  'DIST: GLU 2 CA 15 - GLN 165 CA 2396',
#  'DIST: GLU 2 CA 15 - ALA 166 CA 2413',
#  'DIST: GLU 2 CA 15 - LEU 167 CA 2423',
#  'DIST: GLU 2 CA 15 - LYS 168 CA 2442',
#  'DIST: GLU 2 CA 15 - GLU 169 CA 2464',
#  'DIST: GLU 2 CA 15 - ILE 170 CA 2479',
#  'DIST: GLU 2 CA 15 - GLY 171 CA 2498',
#  'DIST: GLU 2 CA 15 - LYS 172 CA 2505',
#  'DIST: GLU 2 CA 15 - ALA 173 CA 2527',
#  'DIST: GLU 2 CA 15 - LEU 174 CA 2537',
#  'DIST: GLU 2 CA 15 - LYS 175 CA 2556',
#  'DIST: GLU 2 CA 15 - GLU 176 CA 2578',
#  'DIST: GLU 2 CA 15 - ILE 177 CA 2593',
#  'DIST: GLU 2 CA 15 - GLY 178 CA 2612',
#  'DIST: GLU 2 CA 15 - TYR 179 CA 2619',
#  'DIST: GLU 2 CA 15 - ALA 180 CA 2640',
#  'DIST: GLU 2 CA 15 - LEU 181 CA 2650',
#  'DIST: GLU 2 CA 15 - LYS 182 CA 2669',
#  'DIST: GLU 2 CA 15 - GLU 183 CA 2691',
#  'DIST: GLU 2 CA 15 - ILE 184 CA 2706',
#  'DIST: GLU 2 CA 15 - GLY 185 CA 2725',
#  'DIST: GLU 2 CA 15 - GLN 186 CA 2732',
#  'DIST: GLU 2 CA 15 - ALA 187 CA 2749',
#  'DIST: GLU 2 CA 15 - LEU 188 CA 2759',
#  'DIST: GLU 2 CA 15 - LYS 189 CA 2778',
#  'DIST: GLU 2 CA 15 - GLY 190 CA 2800',
#  'DIST: ILE 3 CA 30 - ALA 6 CA 73',
#  'DIST: ILE 3 CA 30 - LEU 7 CA 83',
#  'DIST: ILE 3 CA 30 - LYS 8 CA 102',
#  'DIST: ILE 3 CA 30 - GLU 9 CA 124',
#  'DIST: ILE 3 CA 30 - ILE 10 CA 139',
#  'DIST: ILE 3 CA 30 - GLY 11 CA 158',
#  'DIST: ILE 3 CA 30 - LYS 12 CA 165',
#  'DIST: ILE 3 CA 30 - ALA 13 CA 187',
#  'DIST: ILE 3 CA 30 - LEU 14 CA 197',
#  'DIST: ILE 3 CA 30 - LYS 15 CA 216',
#  'DIST: ILE 3 CA 30 - GLU 16 CA 238',
#  'DIST: ILE 3 CA 30 - ILE 17 CA 253',
#  'DIST: ILE 3 CA 30 - GLY 18 CA 272',
#  'DIST: ILE 3 CA 30 - TYR 19 CA 279',
#  'DIST: ILE 3 CA 30 - ALA 20 CA 300',
#  'DIST: ILE 3 CA 30 - LEU 21 CA 310',
#  'DIST: ILE 3 CA 30 - LYS 22 CA 329',
#  'DIST: ILE 3 CA 30 - GLU 23 CA 351',
#  'DIST: ILE 3 CA 30 - ILE 24 CA 366',
#  'DIST: ILE 3 CA 30 - GLY 25 CA 385',
#  'DIST: ILE 3 CA 30 - GLN 26 CA 392',
#  'DIST: ILE 3 CA 30 - ALA 27 CA 409',
#  'DIST: ILE 3 CA 30 - LEU 28 CA 419',
#  'DIST: ILE 3 CA 30 - LYS 29 CA 438',
#  'DIST: ILE 3 CA 30 - GLY 30 CA 460',
#  'DIST: ILE 3 CA 30 - GLY 33 CA 476',
#  'DIST: ILE 3 CA 30 - GLU 34 CA 483',
#  'DIST: ILE 3 CA 30 - ILE 35 CA 498',
#  'DIST: ILE 3 CA 30 - GLY 36 CA 517',
#  'DIST: ILE 3 CA 30 - GLN 37 CA 524',
#  'DIST: ILE 3 CA 30 - ALA 38 CA 541',
#  'DIST: ILE 3 CA 30 - LEU 39 CA 551',
#  'DIST: ILE 3 CA 30 - LYS 40 CA 570',
#  'DIST: ILE 3 CA 30 - GLU 41 CA 592',
#  'DIST: ILE 3 CA 30 - ILE 42 CA 607',
#  'DIST: ILE 3 CA 30 - GLY 43 CA 626',
#  'DIST: ILE 3 CA 30 - LYS 44 CA 633',
#  'DIST: ILE 3 CA 30 - ALA 45 CA 655',
#  'DIST: ILE 3 CA 30 - LEU 46 CA 665',
#  'DIST: ILE 3 CA 30 - LYS 47 CA 684',
#  'DIST: ILE 3 CA 30 - GLU 48 CA 706',
#  'DIST: ILE 3 CA 30 - ILE 49 CA 721',
#  'DIST: ILE 3 CA 30 - GLY 50 CA 740',
#  'DIST: ILE 3 CA 30 - TYR 51 CA 747',
#  'DIST: ILE 3 CA 30 - ALA 52 CA 768',
#  'DIST: ILE 3 CA 30 - LEU 53 CA 778',
#  'DIST: ILE 3 CA 30 - LYS 54 CA 797',
#  'DIST: ILE 3 CA 30 - GLU 55 CA 819',
#  'DIST: ILE 3 CA 30 - ILE 56 CA 834',
#  'DIST: ILE 3 CA 30 - GLY 57 CA 853',
#  'DIST: ILE 3 CA 30 - GLN 58 CA 860',
#  'DIST: ILE 3 CA 30 - ALA 59 CA 877',
#  'DIST: ILE 3 CA 30 - LEU 60 CA 887',
#  'DIST: ILE 3 CA 30 - LYS 61 CA 906',
#  'DIST: ILE 3 CA 30 - GLY 62 CA 928',
#  'DIST: ILE 3 CA 30 - GLY 65 CA 944',
#  'DIST: ILE 3 CA 30 - GLU 66 CA 951',
#  'DIST: ILE 3 CA 30 - ILE 67 CA 966',
#  'DIST: ILE 3 CA 30 - GLY 68 CA 985',
#  'DIST: ILE 3 CA 30 - GLN 69 CA 992',
#  'DIST: ILE 3 CA 30 - ALA 70 CA 1009',
#  'DIST: ILE 3 CA 30 - LEU 71 CA 1019',
#  'DIST: ILE 3 CA 30 - LYS 72 CA 1038',
#  'DIST: ILE 3 CA 30 - GLU 73 CA 1060',
#  'DIST: ILE 3 CA 30 - ILE 74 CA 1075',
#  'DIST: ILE 3 CA 30 - GLY 75 CA 1094',
#  'DIST: ILE 3 CA 30 - LYS 76 CA 1101',
#  'DIST: ILE 3 CA 30 - ALA 77 CA 1123',
#  'DIST: ILE 3 CA 30 - LEU 78 CA 1133',
#  'DIST: ILE 3 CA 30 - LYS 79 CA 1152',
#  'DIST: ILE 3 CA 30 - GLU 80 CA 1174',
#  'DIST: ILE 3 CA 30 - ILE 81 CA 1189',
#  'DIST: ILE 3 CA 30 - GLY 82 CA 1208',
#  'DIST: ILE 3 CA 30 - TYR 83 CA 1215',
#  'DIST: ILE 3 CA 30 - ALA 84 CA 1236',
#  'DIST: ILE 3 CA 30 - LEU 85 CA 1246',
#  'DIST: ILE 3 CA 30 - LYS 86 CA 1265',
#  'DIST: ILE 3 CA 30 - GLU 87 CA 1287',
#  'DIST: ILE 3 CA 30 - ILE 88 CA 1302',
#  'DIST: ILE 3 CA 30 - GLY 89 CA 1321',
#  'DIST: ILE 3 CA 30 - GLN 90 CA 1328',
#  'DIST: ILE 3 CA 30 - ALA 91 CA 1345',
#  'DIST: ILE 3 CA 30 - LEU 92 CA 1355',
#  'DIST: ILE 3 CA 30 - LYS 93 CA 1374',
#  'DIST: ILE 3 CA 30 - GLY 94 CA 1396',
#  'DIST: ILE 3 CA 30 - GLY 97 CA 1412',
#  'DIST: ILE 3 CA 30 - GLU 98 CA 1419',
#  'DIST: ILE 3 CA 30 - ILE 99 CA 1434',
#  'DIST: ILE 3 CA 30 - GLY 100 CA 1453',
#  'DIST: ILE 3 CA 30 - GLN 101 CA 1460',
#  'DIST: ILE 3 CA 30 - ALA 102 CA 1477',
#  'DIST: ILE 3 CA 30 - LEU 103 CA 1487',
#  'DIST: ILE 3 CA 30 - LYS 104 CA 1506',
#  'DIST: ILE 3 CA 30 - GLU 105 CA 1528',
#  'DIST: ILE 3 CA 30 - ILE 106 CA 1543',
#  'DIST: ILE 3 CA 30 - GLY 107 CA 1562',
#  'DIST: ILE 3 CA 30 - LYS 108 CA 1569',
#  'DIST: ILE 3 CA 30 - ALA 109 CA 1591',
#  'DIST: ILE 3 CA 30 - LEU 110 CA 1601',
#  'DIST: ILE 3 CA 30 - LYS 111 CA 1620',
#  'DIST: ILE 3 CA 30 - GLU 112 CA 1642',
#  'DIST: ILE 3 CA 30 - ILE 113 CA 1657',
#  'DIST: ILE 3 CA 30 - GLY 114 CA 1676',
#  'DIST: ILE 3 CA 30 - TYR 115 CA 1683',
#  'DIST: ILE 3 CA 30 - ALA 116 CA 1704',
#  'DIST: ILE 3 CA 30 - LEU 117 CA 1714',
#  'DIST: ILE 3 CA 30 - LYS 118 CA 1733',
#  'DIST: ILE 3 CA 30 - GLU 119 CA 1755',
#  'DIST: ILE 3 CA 30 - ILE 120 CA 1770',
#  'DIST: ILE 3 CA 30 - GLY 121 CA 1789',
#  'DIST: ILE 3 CA 30 - GLN 122 CA 1796',
#  'DIST: ILE 3 CA 30 - ALA 123 CA 1813',
#  'DIST: ILE 3 CA 30 - LEU 124 CA 1823',
#  'DIST: ILE 3 CA 30 - LYS 125 CA 1842',
#  'DIST: ILE 3 CA 30 - GLY 126 CA 1864',
#  'DIST: ILE 3 CA 30 - GLY 129 CA 1880',
#  'DIST: ILE 3 CA 30 - GLU 130 CA 1887',
#  'DIST: ILE 3 CA 30 - ILE 131 CA 1902',
#  'DIST: ILE 3 CA 30 - GLY 132 CA 1921',
#  'DIST: ILE 3 CA 30 - GLN 133 CA 1928',
#  'DIST: ILE 3 CA 30 - ALA 134 CA 1945',
#  'DIST: ILE 3 CA 30 - LEU 135 CA 1955',
#  'DIST: ILE 3 CA 30 - LYS 136 CA 1974',
#  'DIST: ILE 3 CA 30 - GLU 137 CA 1996',
#  'DIST: ILE 3 CA 30 - ILE 138 CA 2011',
#  'DIST: ILE 3 CA 30 - GLY 139 CA 2030',
#  'DIST: ILE 3 CA 30 - LYS 140 CA 2037',
#  'DIST: ILE 3 CA 30 - ALA 141 CA 2059',
#  'DIST: ILE 3 CA 30 - LEU 142 CA 2069',
#  'DIST: ILE 3 CA 30 - LYS 143 CA 2088',
#  'DIST: ILE 3 CA 30 - GLU 144 CA 2110',
#  'DIST: ILE 3 CA 30 - ILE 145 CA 2125',
#  'DIST: ILE 3 CA 30 - GLY 146 CA 2144',
#  'DIST: ILE 3 CA 30 - TYR 147 CA 2151',
#  'DIST: ILE 3 CA 30 - ALA 148 CA 2172',
#  'DIST: ILE 3 CA 30 - LEU 149 CA 2182',
#  'DIST: ILE 3 CA 30 - LYS 150 CA 2201',
#  'DIST: ILE 3 CA 30 - GLU 151 CA 2223',
#  'DIST: ILE 3 CA 30 - ILE 152 CA 2238',
#  'DIST: ILE 3 CA 30 - GLY 153 CA 2257',
#  'DIST: ILE 3 CA 30 - GLN 154 CA 2264',
#  'DIST: ILE 3 CA 30 - ALA 155 CA 2281',
#  'DIST: ILE 3 CA 30 - LEU 156 CA 2291',
#  'DIST: ILE 3 CA 30 - LYS 157 CA 2310',
#  'DIST: ILE 3 CA 30 - GLY 158 CA 2332',
#  'DIST: ILE 3 CA 30 - GLY 161 CA 2348',
#  'DIST: ILE 3 CA 30 - GLU 162 CA 2355',
#  'DIST: ILE 3 CA 30 - ILE 163 CA 2370',
#  'DIST: ILE 3 CA 30 - GLY 164 CA 2389',
#  'DIST: ILE 3 CA 30 - GLN 165 CA 2396',
#  'DIST: ILE 3 CA 30 - ALA 166 CA 2413',
#  'DIST: ILE 3 CA 30 - LEU 167 CA 2423',
#  'DIST: ILE 3 CA 30 - LYS 168 CA 2442',
#  'DIST: ILE 3 CA 30 - GLU 169 CA 2464',
#  'DIST: ILE 3 CA 30 - ILE 170 CA 2479',
#  'DIST: ILE 3 CA 30 - GLY 171 CA 2498',
#  'DIST: ILE 3 CA 30 - LYS 172 CA 2505',
#  'DIST: ILE 3 CA 30 - ALA 173 CA 2527',
#  'DIST: ILE 3 CA 30 - LEU 174 CA 2537',
#  'DIST: ILE 3 CA 30 - LYS 175 CA 2556',
#  'DIST: ILE 3 CA 30 - GLU 176 CA 2578',
#  'DIST: ILE 3 CA 30 - ILE 177 CA 2593',
#  'DIST: ILE 3 CA 30 - GLY 178 CA 2612',
#  'DIST: ILE 3 CA 30 - TYR 179 CA 2619',
#  'DIST: ILE 3 CA 30 - ALA 180 CA 2640',
#  'DIST: ILE 3 CA 30 - LEU 181 CA 2650',
#  'DIST: ILE 3 CA 30 - LYS 182 CA 2669',
#  'DIST: ILE 3 CA 30 - GLU 183 CA 2691',
#  'DIST: ILE 3 CA 30 - ILE 184 CA 2706',
#  'DIST: ILE 3 CA 30 - GLY 185 CA 2725',
#  'DIST: ILE 3 CA 30 - GLN 186 CA 2732',
#  'DIST: ILE 3 CA 30 - ALA 187 CA 2749',
#  'DIST: ILE 3 CA 30 - LEU 188 CA 2759',
#  'DIST: ILE 3 CA 30 - LYS 189 CA 2778',
#  'DIST: ILE 3 CA 30 - GLY 190 CA 2800',
#  'DIST: GLY 4 CA 49 - LEU 7 CA 83',
#  'DIST: GLY 4 CA 49 - LYS 8 CA 102',
#  'DIST: GLY 4 CA 49 - GLU 9 CA 124',
#  'DIST: GLY 4 CA 49 - ILE 10 CA 139',
#  'DIST: GLY 4 CA 49 - GLY 11 CA 158',
#  'DIST: GLY 4 CA 49 - LYS 12 CA 165',
#  'DIST: GLY 4 CA 49 - ALA 13 CA 187',
#  'DIST: GLY 4 CA 49 - LEU 14 CA 197',
#  'DIST: GLY 4 CA 49 - LYS 15 CA 216',
#  'DIST: GLY 4 CA 49 - GLU 16 CA 238',
#  'DIST: GLY 4 CA 49 - ILE 17 CA 253',
#  'DIST: GLY 4 CA 49 - GLY 18 CA 272',
#  'DIST: GLY 4 CA 49 - TYR 19 CA 279',
#  'DIST: GLY 4 CA 49 - ALA 20 CA 300',
#  'DIST: GLY 4 CA 49 - LEU 21 CA 310',
#  'DIST: GLY 4 CA 49 - LYS 22 CA 329',
#  'DIST: GLY 4 CA 49 - GLU 23 CA 351',
#  'DIST: GLY 4 CA 49 - ILE 24 CA 366',
#  'DIST: GLY 4 CA 49 - GLY 25 CA 385',
#  'DIST: GLY 4 CA 49 - GLN 26 CA 392',
#  'DIST: GLY 4 CA 49 - ALA 27 CA 409',
#  'DIST: GLY 4 CA 49 - LEU 28 CA 419',
#  'DIST: GLY 4 CA 49 - LYS 29 CA 438',
#  'DIST: GLY 4 CA 49 - GLY 30 CA 460',
#  'DIST: GLY 4 CA 49 - GLY 33 CA 476',
#  'DIST: GLY 4 CA 49 - GLU 34 CA 483',
#  'DIST: GLY 4 CA 49 - ILE 35 CA 498',
#  'DIST: GLY 4 CA 49 - GLY 36 CA 517',
#  'DIST: GLY 4 CA 49 - GLN 37 CA 524',
#  'DIST: GLY 4 CA 49 - ALA 38 CA 541',
#  'DIST: GLY 4 CA 49 - LEU 39 CA 551',
#  'DIST: GLY 4 CA 49 - LYS 40 CA 570',
#  'DIST: GLY 4 CA 49 - GLU 41 CA 592',
#  'DIST: GLY 4 CA 49 - ILE 42 CA 607',
#  'DIST: GLY 4 CA 49 - GLY 43 CA 626',
#  'DIST: GLY 4 CA 49 - LYS 44 CA 633',
#  'DIST: GLY 4 CA 49 - ALA 45 CA 655',
#  'DIST: GLY 4 CA 49 - LEU 46 CA 665',
#  'DIST: GLY 4 CA 49 - LYS 47 CA 684',
#  'DIST: GLY 4 CA 49 - GLU 48 CA 706',
#  'DIST: GLY 4 CA 49 - ILE 49 CA 721',
#  'DIST: GLY 4 CA 49 - GLY 50 CA 740',
#  'DIST: GLY 4 CA 49 - TYR 51 CA 747',
#  'DIST: GLY 4 CA 49 - ALA 52 CA 768',
#  'DIST: GLY 4 CA 49 - LEU 53 CA 778',
#  'DIST: GLY 4 CA 49 - LYS 54 CA 797',
#  'DIST: GLY 4 CA 49 - GLU 55 CA 819',
#  'DIST: GLY 4 CA 49 - ILE 56 CA 834',
#  'DIST: GLY 4 CA 49 - GLY 57 CA 853',
#  'DIST: GLY 4 CA 49 - GLN 58 CA 860',
#  'DIST: GLY 4 CA 49 - ALA 59 CA 877',
#  'DIST: GLY 4 CA 49 - LEU 60 CA 887',
#  'DIST: GLY 4 CA 49 - LYS 61 CA 906',
#  'DIST: GLY 4 CA 49 - GLY 62 CA 928',
#  'DIST: GLY 4 CA 49 - GLY 65 CA 944',
#  'DIST: GLY 4 CA 49 - GLU 66 CA 951',
#  'DIST: GLY 4 CA 49 - ILE 67 CA 966',
#  'DIST: GLY 4 CA 49 - GLY 68 CA 985',
#  'DIST: GLY 4 CA 49 - GLN 69 CA 992',
#  'DIST: GLY 4 CA 49 - ALA 70 CA 1009',
#  'DIST: GLY 4 CA 49 - LEU 71 CA 1019',
#  'DIST: GLY 4 CA 49 - LYS 72 CA 1038',
#  'DIST: GLY 4 CA 49 - GLU 73 CA 1060',
#  'DIST: GLY 4 CA 49 - ILE 74 CA 1075',
#  'DIST: GLY 4 CA 49 - GLY 75 CA 1094',
#  'DIST: GLY 4 CA 49 - LYS 76 CA 1101',
#  'DIST: GLY 4 CA 49 - ALA 77 CA 1123',
#  'DIST: GLY 4 CA 49 - LEU 78 CA 1133',
#  'DIST: GLY 4 CA 49 - LYS 79 CA 1152',
#  'DIST: GLY 4 CA 49 - GLU 80 CA 1174',
#  'DIST: GLY 4 CA 49 - ILE 81 CA 1189',
#  'DIST: GLY 4 CA 49 - GLY 82 CA 1208',
#  'DIST: GLY 4 CA 49 - TYR 83 CA 1215',
#  'DIST: GLY 4 CA 49 - ALA 84 CA 1236',
#  'DIST: GLY 4 CA 49 - LEU 85 CA 1246',
#  'DIST: GLY 4 CA 49 - LYS 86 CA 1265',
#  'DIST: GLY 4 CA 49 - GLU 87 CA 1287',
#  'DIST: GLY 4 CA 49 - ILE 88 CA 1302',
#  'DIST: GLY 4 CA 49 - GLY 89 CA 1321',
#  'DIST: GLY 4 CA 49 - GLN 90 CA 1328',
#  'DIST: GLY 4 CA 49 - ALA 91 CA 1345',
#  'DIST: GLY 4 CA 49 - LEU 92 CA 1355',
#  'DIST: GLY 4 CA 49 - LYS 93 CA 1374',
#  'DIST: GLY 4 CA 49 - GLY 94 CA 1396',
#  'DIST: GLY 4 CA 49 - GLY 97 CA 1412',
#  'DIST: GLY 4 CA 49 - GLU 98 CA 1419',
#  'DIST: GLY 4 CA 49 - ILE 99 CA 1434',
#  'DIST: GLY 4 CA 49 - GLY 100 CA 1453',
#  'DIST: GLY 4 CA 49 - GLN 101 CA 1460',
#  'DIST: GLY 4 CA 49 - ALA 102 CA 1477',
#  'DIST: GLY 4 CA 49 - LEU 103 CA 1487',
#  'DIST: GLY 4 CA 49 - LYS 104 CA 1506',
#  'DIST: GLY 4 CA 49 - GLU 105 CA 1528',
#  'DIST: GLY 4 CA 49 - ILE 106 CA 1543',
#  'DIST: GLY 4 CA 49 - GLY 107 CA 1562',
#  'DIST: GLY 4 CA 49 - LYS 108 CA 1569',
#  'DIST: GLY 4 CA 49 - ALA 109 CA 1591',
#  'DIST: GLY 4 CA 49 - LEU 110 CA 1601',
#  'DIST: GLY 4 CA 49 - LYS 111 CA 1620',
#  'DIST: GLY 4 CA 49 - GLU 112 CA 1642',
#  'DIST: GLY 4 CA 49 - ILE 113 CA 1657',
#  'DIST: GLY 4 CA 49 - GLY 114 CA 1676',
#  'DIST: GLY 4 CA 49 - TYR 115 CA 1683',
#  'DIST: GLY 4 CA 49 - ALA 116 CA 1704',
#  'DIST: GLY 4 CA 49 - LEU 117 CA 1714',
#  'DIST: GLY 4 CA 49 - LYS 118 CA 1733',
#  'DIST: GLY 4 CA 49 - GLU 119 CA 1755',
#  'DIST: GLY 4 CA 49 - ILE 120 CA 1770',
#  'DIST: GLY 4 CA 49 - GLY 121 CA 1789',
#  'DIST: GLY 4 CA 49 - GLN 122 CA 1796',
#  'DIST: GLY 4 CA 49 - ALA 123 CA 1813',
#  'DIST: GLY 4 CA 49 - LEU 124 CA 1823',
#  'DIST: GLY 4 CA 49 - LYS 125 CA 1842',
#  'DIST: GLY 4 CA 49 - GLY 126 CA 1864',
#  'DIST: GLY 4 CA 49 - GLY 129 CA 1880',
#  'DIST: GLY 4 CA 49 - GLU 130 CA 1887',
#  'DIST: GLY 4 CA 49 - ILE 131 CA 1902',
#  'DIST: GLY 4 CA 49 - GLY 132 CA 1921',
#  'DIST: GLY 4 CA 49 - GLN 133 CA 1928',
#  'DIST: GLY 4 CA 49 - ALA 134 CA 1945',
#  'DIST: GLY 4 CA 49 - LEU 135 CA 1955',
#  'DIST: GLY 4 CA 49 - LYS 136 CA 1974',
#  'DIST: GLY 4 CA 49 - GLU 137 CA 1996',
#  'DIST: GLY 4 CA 49 - ILE 138 CA 2011',
#  'DIST: GLY 4 CA 49 - GLY 139 CA 2030',
#  'DIST: GLY 4 CA 49 - LYS 140 CA 2037',
#  'DIST: GLY 4 CA 49 - ALA 141 CA 2059',
#  'DIST: GLY 4 CA 49 - LEU 142 CA 2069',
#  'DIST: GLY 4 CA 49 - LYS 143 CA 2088',
#  'DIST: GLY 4 CA 49 - GLU 144 CA 2110',
#  'DIST: GLY 4 CA 49 - ILE 145 CA 2125',
#  'DIST: GLY 4 CA 49 - GLY 146 CA 2144',
#  'DIST: GLY 4 CA 49 - TYR 147 CA 2151',
#  'DIST: GLY 4 CA 49 - ALA 148 CA 2172',
#  'DIST: GLY 4 CA 49 - LEU 149 CA 2182',
#  'DIST: GLY 4 CA 49 - LYS 150 CA 2201',
#  'DIST: GLY 4 CA 49 - GLU 151 CA 2223',
#  'DIST: GLY 4 CA 49 - ILE 152 CA 2238',
#  'DIST: GLY 4 CA 49 - GLY 153 CA 2257',
#  'DIST: GLY 4 CA 49 - GLN 154 CA 2264',
#  'DIST: GLY 4 CA 49 - ALA 155 CA 2281',
#  'DIST: GLY 4 CA 49 - LEU 156 CA 2291',
#  'DIST: GLY 4 CA 49 - LYS 157 CA 2310',
#  'DIST: GLY 4 CA 49 - GLY 158 CA 2332',
#  'DIST: GLY 4 CA 49 - GLY 161 CA 2348',
#  'DIST: GLY 4 CA 49 - GLU 162 CA 2355',
#  'DIST: GLY 4 CA 49 - ILE 163 CA 2370',
#  'DIST: GLY 4 CA 49 - GLY 164 CA 2389',
#  'DIST: GLY 4 CA 49 - GLN 165 CA 2396',
#  'DIST: GLY 4 CA 49 - ALA 166 CA 2413',
#  'DIST: GLY 4 CA 49 - LEU 167 CA 2423',
#  'DIST: GLY 4 CA 49 - LYS 168 CA 2442',
#  'DIST: GLY 4 CA 49 - GLU 169 CA 2464',
#  'DIST: GLY 4 CA 49 - ILE 170 CA 2479',
#  'DIST: GLY 4 CA 49 - GLY 171 CA 2498',
#  'DIST: GLY 4 CA 49 - LYS 172 CA 2505',
#  'DIST: GLY 4 CA 49 - ALA 173 CA 2527',
#  'DIST: GLY 4 CA 49 - LEU 174 CA 2537',
#  'DIST: GLY 4 CA 49 - LYS 175 CA 2556',
#  'DIST: GLY 4 CA 49 - GLU 176 CA 2578',
#  'DIST: GLY 4 CA 49 - ILE 177 CA 2593',
#  'DIST: GLY 4 CA 49 - GLY 178 CA 2612',
#  'DIST: GLY 4 CA 49 - TYR 179 CA 2619',
#  'DIST: GLY 4 CA 49 - ALA 180 CA 2640',
#  'DIST: GLY 4 CA 49 - LEU 181 CA 2650',
#  'DIST: GLY 4 CA 49 - LYS 182 CA 2669',
#  'DIST: GLY 4 CA 49 - GLU 183 CA 2691',
#  'DIST: GLY 4 CA 49 - ILE 184 CA 2706',
#  'DIST: GLY 4 CA 49 - GLY 185 CA 2725',
#  'DIST: GLY 4 CA 49 - GLN 186 CA 2732',
#  'DIST: GLY 4 CA 49 - ALA 187 CA 2749',
#  'DIST: GLY 4 CA 49 - LEU 188 CA 2759',
#  'DIST: GLY 4 CA 49 - LYS 189 CA 2778',
#  'DIST: GLY 4 CA 49 - GLY 190 CA 2800',
#  'DIST: GLN 5 CA 56 - LYS 8 CA 102',
#  'DIST: GLN 5 CA 56 - GLU 9 CA 124',
#  'DIST: GLN 5 CA 56 - ILE 10 CA 139',
#  'DIST: GLN 5 CA 56 - GLY 11 CA 158',
#  'DIST: GLN 5 CA 56 - LYS 12 CA 165',
#  'DIST: GLN 5 CA 56 - ALA 13 CA 187',
#  'DIST: GLN 5 CA 56 - LEU 14 CA 197',
#  'DIST: GLN 5 CA 56 - LYS 15 CA 216',
#  'DIST: GLN 5 CA 56 - GLU 16 CA 238',
#  'DIST: GLN 5 CA 56 - ILE 17 CA 253',
#  'DIST: GLN 5 CA 56 - GLY 18 CA 272',
#  'DIST: GLN 5 CA 56 - TYR 19 CA 279',
#  'DIST: GLN 5 CA 56 - ALA 20 CA 300',
#  'DIST: GLN 5 CA 56 - LEU 21 CA 310',
#  'DIST: GLN 5 CA 56 - LYS 22 CA 329',
#  'DIST: GLN 5 CA 56 - GLU 23 CA 351',
#  'DIST: GLN 5 CA 56 - ILE 24 CA 366',
#  'DIST: GLN 5 CA 56 - GLY 25 CA 385',
#  'DIST: GLN 5 CA 56 - GLN 26 CA 392',
#  'DIST: GLN 5 CA 56 - ALA 27 CA 409',
#  'DIST: GLN 5 CA 56 - LEU 28 CA 419',
#  'DIST: GLN 5 CA 56 - LYS 29 CA 438',
#  'DIST: GLN 5 CA 56 - GLY 30 CA 460',
#  'DIST: GLN 5 CA 56 - GLY 33 CA 476',
#  'DIST: GLN 5 CA 56 - GLU 34 CA 483',
#  'DIST: GLN 5 CA 56 - ILE 35 CA 498',
#  'DIST: GLN 5 CA 56 - GLY 36 CA 517',
#  'DIST: GLN 5 CA 56 - GLN 37 CA 524',
#  'DIST: GLN 5 CA 56 - ALA 38 CA 541',
#  'DIST: GLN 5 CA 56 - LEU 39 CA 551',
#  'DIST: GLN 5 CA 56 - LYS 40 CA 570',
#  'DIST: GLN 5 CA 56 - GLU 41 CA 592',
#  'DIST: GLN 5 CA 56 - ILE 42 CA 607',
#  'DIST: GLN 5 CA 56 - GLY 43 CA 626',
#  'DIST: GLN 5 CA 56 - LYS 44 CA 633',
#  'DIST: GLN 5 CA 56 - ALA 45 CA 655',
#  'DIST: GLN 5 CA 56 - LEU 46 CA 665',
#  'DIST: GLN 5 CA 56 - LYS 47 CA 684',
#  'DIST: GLN 5 CA 56 - GLU 48 CA 706',
#  'DIST: GLN 5 CA 56 - ILE 49 CA 721',
#  'DIST: GLN 5 CA 56 - GLY 50 CA 740',
#  'DIST: GLN 5 CA 56 - TYR 51 CA 747',
#  'DIST: GLN 5 CA 56 - ALA 52 CA 768',
#  'DIST: GLN 5 CA 56 - LEU 53 CA 778',
#  'DIST: GLN 5 CA 56 - LYS 54 CA 797',
#  'DIST: GLN 5 CA 56 - GLU 55 CA 819',
#  'DIST: GLN 5 CA 56 - ILE 56 CA 834',
#  'DIST: GLN 5 CA 56 - GLY 57 CA 853',
#  'DIST: GLN 5 CA 56 - GLN 58 CA 860',
#  'DIST: GLN 5 CA 56 - ALA 59 CA 877',
#  'DIST: GLN 5 CA 56 - LEU 60 CA 887',
#  'DIST: GLN 5 CA 56 - LYS 61 CA 906',
#  'DIST: GLN 5 CA 56 - GLY 62 CA 928',
#  'DIST: GLN 5 CA 56 - GLY 65 CA 944',
#  'DIST: GLN 5 CA 56 - GLU 66 CA 951',
#  'DIST: GLN 5 CA 56 - ILE 67 CA 966',
#  'DIST: GLN 5 CA 56 - GLY 68 CA 985',
#  'DIST: GLN 5 CA 56 - GLN 69 CA 992',
#  'DIST: GLN 5 CA 56 - ALA 70 CA 1009',
#  'DIST: GLN 5 CA 56 - LEU 71 CA 1019',
#  'DIST: GLN 5 CA 56 - LYS 72 CA 1038',
#  'DIST: GLN 5 CA 56 - GLU 73 CA 1060',
#  'DIST: GLN 5 CA 56 - ILE 74 CA 1075',
#  'DIST: GLN 5 CA 56 - GLY 75 CA 1094',
#  'DIST: GLN 5 CA 56 - LYS 76 CA 1101',
#  'DIST: GLN 5 CA 56 - ALA 77 CA 1123',
#  'DIST: GLN 5 CA 56 - LEU 78 CA 1133',
#  'DIST: GLN 5 CA 56 - LYS 79 CA 1152',
#  'DIST: GLN 5 CA 56 - GLU 80 CA 1174',
#  'DIST: GLN 5 CA 56 - ILE 81 CA 1189',
#  'DIST: GLN 5 CA 56 - GLY 82 CA 1208',
#  'DIST: GLN 5 CA 56 - TYR 83 CA 1215',
#  'DIST: GLN 5 CA 56 - ALA 84 CA 1236',
#  'DIST: GLN 5 CA 56 - LEU 85 CA 1246',
#  'DIST: GLN 5 CA 56 - LYS 86 CA 1265',
#  'DIST: GLN 5 CA 56 - GLU 87 CA 1287',
#  'DIST: GLN 5 CA 56 - ILE 88 CA 1302',
#  'DIST: GLN 5 CA 56 - GLY 89 CA 1321',
#  'DIST: GLN 5 CA 56 - GLN 90 CA 1328',
#  'DIST: GLN 5 CA 56 - ALA 91 CA 1345',
#  'DIST: GLN 5 CA 56 - LEU 92 CA 1355',
#  'DIST: GLN 5 CA 56 - LYS 93 CA 1374',
#  'DIST: GLN 5 CA 56 - GLY 94 CA 1396',
#  'DIST: GLN 5 CA 56 - GLY 97 CA 1412',
#  'DIST: GLN 5 CA 56 - GLU 98 CA 1419',
#  'DIST: GLN 5 CA 56 - ILE 99 CA 1434',
#  'DIST: GLN 5 CA 56 - GLY 100 CA 1453',
#  'DIST: GLN 5 CA 56 - GLN 101 CA 1460',
#  'DIST: GLN 5 CA 56 - ALA 102 CA 1477',
#  'DIST: GLN 5 CA 56 - LEU 103 CA 1487',
#  'DIST: GLN 5 CA 56 - LYS 104 CA 1506',
#  'DIST: GLN 5 CA 56 - GLU 105 CA 1528',
#  'DIST: GLN 5 CA 56 - ILE 106 CA 1543',
#  'DIST: GLN 5 CA 56 - GLY 107 CA 1562',
#  'DIST: GLN 5 CA 56 - LYS 108 CA 1569',
#  'DIST: GLN 5 CA 56 - ALA 109 CA 1591',
#  'DIST: GLN 5 CA 56 - LEU 110 CA 1601',
#  'DIST: GLN 5 CA 56 - LYS 111 CA 1620',
#  'DIST: GLN 5 CA 56 - GLU 112 CA 1642',
#  'DIST: GLN 5 CA 56 - ILE 113 CA 1657',
#  'DIST: GLN 5 CA 56 - GLY 114 CA 1676',
#  'DIST: GLN 5 CA 56 - TYR 115 CA 1683',
#  'DIST: GLN 5 CA 56 - ALA 116 CA 1704',
#  'DIST: GLN 5 CA 56 - LEU 117 CA 1714',
#  'DIST: GLN 5 CA 56 - LYS 118 CA 1733',
#  'DIST: GLN 5 CA 56 - GLU 119 CA 1755',
#  'DIST: GLN 5 CA 56 - ILE 120 CA 1770',
#  'DIST: GLN 5 CA 56 - GLY 121 CA 1789',
#  'DIST: GLN 5 CA 56 - GLN 122 CA 1796',
#  'DIST: GLN 5 CA 56 - ALA 123 CA 1813',
#  'DIST: GLN 5 CA 56 - LEU 124 CA 1823',
#  'DIST: GLN 5 CA 56 - LYS 125 CA 1842',
#  'DIST: GLN 5 CA 56 - GLY 126 CA 1864',
#  'DIST: GLN 5 CA 56 - GLY 129 CA 1880',
#  'DIST: GLN 5 CA 56 - GLU 130 CA 1887',
#  'DIST: GLN 5 CA 56 - ILE 131 CA 1902',
#  'DIST: GLN 5 CA 56 - GLY 132 CA 1921',
#  'DIST: GLN 5 CA 56 - GLN 133 CA 1928',
#  'DIST: GLN 5 CA 56 - ALA 134 CA 1945',
#  'DIST: GLN 5 CA 56 - LEU 135 CA 1955',
#  'DIST: GLN 5 CA 56 - LYS 136 CA 1974',
#  'DIST: GLN 5 CA 56 - GLU 137 CA 1996',
#  'DIST: GLN 5 CA 56 - ILE 138 CA 2011',
#  'DIST: GLN 5 CA 56 - GLY 139 CA 2030',
#  'DIST: GLN 5 CA 56 - LYS 140 CA 2037',
#  'DIST: GLN 5 CA 56 - ALA 141 CA 2059',
#  'DIST: GLN 5 CA 56 - LEU 142 CA 2069',
#  'DIST: GLN 5 CA 56 - LYS 143 CA 2088',
#  'DIST: GLN 5 CA 56 - GLU 144 CA 2110',
#  'DIST: GLN 5 CA 56 - ILE 145 CA 2125',
#  'DIST: GLN 5 CA 56 - GLY 146 CA 2144',
#  'DIST: GLN 5 CA 56 - TYR 147 CA 2151',
#  'DIST: GLN 5 CA 56 - ALA 148 CA 2172',
#  'DIST: GLN 5 CA 56 - LEU 149 CA 2182',
#  'DIST: GLN 5 CA 56 - LYS 150 CA 2201',
#  'DIST: GLN 5 CA 56 - GLU 151 CA 2223',
#  'DIST: GLN 5 CA 56 - ILE 152 CA 2238',
#  'DIST: GLN 5 CA 56 - GLY 153 CA 2257',
#  'DIST: GLN 5 CA 56 - GLN 154 CA 2264',
#  'DIST: GLN 5 CA 56 - ALA 155 CA 2281',
#  'DIST: GLN 5 CA 56 - LEU 156 CA 2291',
#  'DIST: GLN 5 CA 56 - LYS 157 CA 2310',
#  'DIST: GLN 5 CA 56 - GLY 158 CA 2332',
#  'DIST: GLN 5 CA 56 - GLY 161 CA 2348',
#  'DIST: GLN 5 CA 56 - GLU 162 CA 2355',
#  'DIST: GLN 5 CA 56 - ILE 163 CA 2370',
#  'DIST: GLN 5 CA 56 - GLY 164 CA 2389',
#  'DIST: GLN 5 CA 56 - GLN 165 CA 2396',
#  'DIST: GLN 5 CA 56 - ALA 166 CA 2413',
#  'DIST: GLN 5 CA 56 - LEU 167 CA 2423',
#  'DIST: GLN 5 CA 56 - LYS 168 CA 2442',
#  'DIST: GLN 5 CA 56 - GLU 169 CA 2464',
#  'DIST: GLN 5 CA 56 - ILE 170 CA 2479',
#  'DIST: GLN 5 CA 56 - GLY 171 CA 2498',
#  'DIST: GLN 5 CA 56 - LYS 172 CA 2505',
#  'DIST: GLN 5 CA 56 - ALA 173 CA 2527',
#  'DIST: GLN 5 CA 56 - LEU 174 CA 2537',
#  'DIST: GLN 5 CA 56 - LYS 175 CA 2556',
#  'DIST: GLN 5 CA 56 - GLU 176 CA 2578',
#  'DIST: GLN 5 CA 56 - ILE 177 CA 2593',
#  'DIST: GLN 5 CA 56 - GLY 178 CA 2612',
#  'DIST: GLN 5 CA 56 - TYR 179 CA 2619',
#  'DIST: GLN 5 CA 56 - ALA 180 CA 2640',
#  'DIST: GLN 5 CA 56 - LEU 181 CA 2650',
#  'DIST: GLN 5 CA 56 - LYS 182 CA 2669',
#  'DIST: GLN 5 CA 56 - GLU 183 CA 2691',
#  'DIST: GLN 5 CA 56 - ILE 184 CA 2706',
#  'DIST: GLN 5 CA 56 - GLY 185 CA 2725',
#  'DIST: GLN 5 CA 56 - GLN 186 CA 2732',
#  'DIST: GLN 5 CA 56 - ALA 187 CA 2749',
#  'DIST: GLN 5 CA 56 - LEU 188 CA 2759',
#  'DIST: GLN 5 CA 56 - LYS 189 CA 2778',
#  'DIST: GLN 5 CA 56 - GLY 190 CA 2800',
#  'DIST: ALA 6 CA 73 - GLU 9 CA 124',
#  'DIST: ALA 6 CA 73 - ILE 10 CA 139',
#  'DIST: ALA 6 CA 73 - GLY 11 CA 158',
#  'DIST: ALA 6 CA 73 - LYS 12 CA 165',
#  'DIST: ALA 6 CA 73 - ALA 13 CA 187',
#  'DIST: ALA 6 CA 73 - LEU 14 CA 197',
#  'DIST: ALA 6 CA 73 - LYS 15 CA 216',
#  'DIST: ALA 6 CA 73 - GLU 16 CA 238',
#  'DIST: ALA 6 CA 73 - ILE 17 CA 253',
#  'DIST: ALA 6 CA 73 - GLY 18 CA 272',
#  'DIST: ALA 6 CA 73 - TYR 19 CA 279',
#  'DIST: ALA 6 CA 73 - ALA 20 CA 300',
#  'DIST: ALA 6 CA 73 - LEU 21 CA 310',
#  'DIST: ALA 6 CA 73 - LYS 22 CA 329',
#  'DIST: ALA 6 CA 73 - GLU 23 CA 351',
#  'DIST: ALA 6 CA 73 - ILE 24 CA 366',
#  'DIST: ALA 6 CA 73 - GLY 25 CA 385',
#  'DIST: ALA 6 CA 73 - GLN 26 CA 392',
#  'DIST: ALA 6 CA 73 - ALA 27 CA 409',
#  'DIST: ALA 6 CA 73 - LEU 28 CA 419',
#  'DIST: ALA 6 CA 73 - LYS 29 CA 438',
#  'DIST: ALA 6 CA 73 - GLY 30 CA 460',
#  'DIST: ALA 6 CA 73 - GLY 33 CA 476',
#  'DIST: ALA 6 CA 73 - GLU 34 CA 483',
#  'DIST: ALA 6 CA 73 - ILE 35 CA 498',
#  'DIST: ALA 6 CA 73 - GLY 36 CA 517',
#  'DIST: ALA 6 CA 73 - GLN 37 CA 524',
#  'DIST: ALA 6 CA 73 - ALA 38 CA 541',
#  'DIST: ALA 6 CA 73 - LEU 39 CA 551',
#  'DIST: ALA 6 CA 73 - LYS 40 CA 570',
#  'DIST: ALA 6 CA 73 - GLU 41 CA 592',
#  'DIST: ALA 6 CA 73 - ILE 42 CA 607',
#  'DIST: ALA 6 CA 73 - GLY 43 CA 626',
#  'DIST: ALA 6 CA 73 - LYS 44 CA 633',
#  'DIST: ALA 6 CA 73 - ALA 45 CA 655',
#  'DIST: ALA 6 CA 73 - LEU 46 CA 665',
#  'DIST: ALA 6 CA 73 - LYS 47 CA 684',
#  'DIST: ALA 6 CA 73 - GLU 48 CA 706',
#  'DIST: ALA 6 CA 73 - ILE 49 CA 721',
#  'DIST: ALA 6 CA 73 - GLY 50 CA 740',
#  'DIST: ALA 6 CA 73 - TYR 51 CA 747',
#  'DIST: ALA 6 CA 73 - ALA 52 CA 768',
#  'DIST: ALA 6 CA 73 - LEU 53 CA 778',
#  'DIST: ALA 6 CA 73 - LYS 54 CA 797',
#  'DIST: ALA 6 CA 73 - GLU 55 CA 819',
#  'DIST: ALA 6 CA 73 - ILE 56 CA 834',
#  'DIST: ALA 6 CA 73 - GLY 57 CA 853',
#  'DIST: ALA 6 CA 73 - GLN 58 CA 860',
#  'DIST: ALA 6 CA 73 - ALA 59 CA 877',
#  'DIST: ALA 6 CA 73 - LEU 60 CA 887',
#  'DIST: ALA 6 CA 73 - LYS 61 CA 906',
#  'DIST: ALA 6 CA 73 - GLY 62 CA 928',
#  'DIST: ALA 6 CA 73 - GLY 65 CA 944',
#  'DIST: ALA 6 CA 73 - GLU 66 CA 951',
#  'DIST: ALA 6 CA 73 - ILE 67 CA 966',
#  'DIST: ALA 6 CA 73 - GLY 68 CA 985',
#  'DIST: ALA 6 CA 73 - GLN 69 CA 992',
#  'DIST: ALA 6 CA 73 - ALA 70 CA 1009',
#  'DIST: ALA 6 CA 73 - LEU 71 CA 1019',
#  'DIST: ALA 6 CA 73 - LYS 72 CA 1038',
#  'DIST: ALA 6 CA 73 - GLU 73 CA 1060',
#  'DIST: ALA 6 CA 73 - ILE 74 CA 1075',
#  'DIST: ALA 6 CA 73 - GLY 75 CA 1094',
#  'DIST: ALA 6 CA 73 - LYS 76 CA 1101',
#  'DIST: ALA 6 CA 73 - ALA 77 CA 1123',
#  'DIST: ALA 6 CA 73 - LEU 78 CA 1133',
#  'DIST: ALA 6 CA 73 - LYS 79 CA 1152',
#  'DIST: ALA 6 CA 73 - GLU 80 CA 1174',
#  'DIST: ALA 6 CA 73 - ILE 81 CA 1189',
#  'DIST: ALA 6 CA 73 - GLY 82 CA 1208',
#  'DIST: ALA 6 CA 73 - TYR 83 CA 1215',
#  'DIST: ALA 6 CA 73 - ALA 84 CA 1236',
#  'DIST: ALA 6 CA 73 - LEU 85 CA 1246',
#  'DIST: ALA 6 CA 73 - LYS 86 CA 1265',
#  'DIST: ALA 6 CA 73 - GLU 87 CA 1287',
#  'DIST: ALA 6 CA 73 - ILE 88 CA 1302',
#  'DIST: ALA 6 CA 73 - GLY 89 CA 1321',
#  'DIST: ALA 6 CA 73 - GLN 90 CA 1328',
#  'DIST: ALA 6 CA 73 - ALA 91 CA 1345',
#  'DIST: ALA 6 CA 73 - LEU 92 CA 1355',
#  'DIST: ALA 6 CA 73 - LYS 93 CA 1374',
#  'DIST: ALA 6 CA 73 - GLY 94 CA 1396',
#  'DIST: ALA 6 CA 73 - GLY 97 CA 1412',
#  'DIST: ALA 6 CA 73 - GLU 98 CA 1419',
#  'DIST: ALA 6 CA 73 - ILE 99 CA 1434',
#  'DIST: ALA 6 CA 73 - GLY 100 CA 1453',
#  'DIST: ALA 6 CA 73 - GLN 101 CA 1460',
#  'DIST: ALA 6 CA 73 - ALA 102 CA 1477',
#  'DIST: ALA 6 CA 73 - LEU 103 CA 1487',
#  'DIST: ALA 6 CA 73 - LYS 104 CA 1506',
#  'DIST: ALA 6 CA 73 - GLU 105 CA 1528',
#  'DIST: ALA 6 CA 73 - ILE 106 CA 1543',
#  'DIST: ALA 6 CA 73 - GLY 107 CA 1562',
#  'DIST: ALA 6 CA 73 - LYS 108 CA 1569',
#  'DIST: ALA 6 CA 73 - ALA 109 CA 1591',
#  'DIST: ALA 6 CA 73 - LEU 110 CA 1601',
#  'DIST: ALA 6 CA 73 - LYS 111 CA 1620',
#  'DIST: ALA 6 CA 73 - GLU 112 CA 1642',
#  'DIST: ALA 6 CA 73 - ILE 113 CA 1657',
#  'DIST: ALA 6 CA 73 - GLY 114 CA 1676',
#  'DIST: ALA 6 CA 73 - TYR 115 CA 1683',
#  'DIST: ALA 6 CA 73 - ALA 116 CA 1704',
#  'DIST: ALA 6 CA 73 - LEU 117 CA 1714',
#  'DIST: ALA 6 CA 73 - LYS 118 CA 1733',
#  'DIST: ALA 6 CA 73 - GLU 119 CA 1755',
#  'DIST: ALA 6 CA 73 - ILE 120 CA 1770',
#  'DIST: ALA 6 CA 73 - GLY 121 CA 1789',
#  'DIST: ALA 6 CA 73 - GLN 122 CA 1796',
#  'DIST: ALA 6 CA 73 - ALA 123 CA 1813',
#  'DIST: ALA 6 CA 73 - LEU 124 CA 1823',
#  'DIST: ALA 6 CA 73 - LYS 125 CA 1842',
#  'DIST: ALA 6 CA 73 - GLY 126 CA 1864',
#  'DIST: ALA 6 CA 73 - GLY 129 CA 1880',
#  'DIST: ALA 6 CA 73 - GLU 130 CA 1887',
#  'DIST: ALA 6 CA 73 - ILE 131 CA 1902',
#  'DIST: ALA 6 CA 73 - GLY 132 CA 1921',
#  'DIST: ALA 6 CA 73 - GLN 133 CA 1928',
#  'DIST: ALA 6 CA 73 - ALA 134 CA 1945',
#  'DIST: ALA 6 CA 73 - LEU 135 CA 1955',
#  'DIST: ALA 6 CA 73 - LYS 136 CA 1974',
#  'DIST: ALA 6 CA 73 - GLU 137 CA 1996',
#  'DIST: ALA 6 CA 73 - ILE 138 CA 2011',
#  'DIST: ALA 6 CA 73 - GLY 139 CA 2030',
#  'DIST: ALA 6 CA 73 - LYS 140 CA 2037',
#  'DIST: ALA 6 CA 73 - ALA 141 CA 2059',
#  ...]

# %%
feat.dimension()
# Out:
# 15768

# %%
inp = pyemma.coordinates.load(trajfile, stride=100, features=feat)

# %%
tica_obj = pyemma.coordinates.tica(data=inp, lag=20, var_cutoff=0.95)
print('TICA dimension ', tica_obj.dimension())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-08f2e09222a7> in <module>()
# ----> 1 tica_obj = pyemma.coordinates.tica(data=inp, lag=20, var_cutoff=0.95)
#       2 print('TICA dimension ', tica_obj.dimension())
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/coordinates/api.py in tica(data, lag, dim, var_cutoff, kinetic_map, commute_map, weights, stride, remove_mean, skip, reversible, ncov_max, chunksize, **kwargs)
#    1259                weights=weights, reversible=reversible, ncov_max=ncov_max)
#    1260     if data is not None:
# -> 1261         res.estimate(data, chunksize=cs)
#    1262     else:
#    1263         res.chunksize = cs
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/coordinates/transform/tica.py in estimate(self, X, **kwargs)
#     157         the independent components.
#     158         """
# --> 159         return super(TICA, self).estimate(X, **kwargs)
#     160
#     161     def partial_fit(self, X):
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/coordinates/data/_base/transformer.py in estimate(self, X, **kwargs)
#     210     """ Basis class for pipelined Transformers, which perform also estimation. """
#     211     def estimate(self, X, **kwargs):
# --> 212         super(StreamingEstimationTransformer, self).estimate(X, **kwargs)
#     213         # we perform the mapping to memory exactly here, because a StreamingEstimator on its own
#     214         # has not output to be mapped. Only the combination of Estimation/Transforming has this feature.
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/coordinates/data/_base/streaming_estimator.py in estimate(self, X, chunksize, **kwargs)
#      43         # run estimation
#      44         try:
# ---> 45             super(StreamingEstimator, self).estimate(X, **kwargs)
#      46         except NotConvergedWarning as ncw:
#      47             self.logger.info(
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/_base/estimator.py in estimate(self, X, **params)
#     410         if params:
#     411             self.set_params(**params)
# --> 412         self._model = self._estimate(X)
#     413         # ensure _estimate returned something
#     414         assert self._model is not None
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/coordinates/transform/tica.py in _estimate(self, iterable, **kw)
#     208                                         cov=covar.C00_,
#     209                                         cov_tau=covar.C0t_)
# --> 210         self._diagonalize()
#     211
#     212         return self.model
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/coordinates/transform/tica.py in _diagonalize(self)
#     216         self.logger.debug("diagonalize Cov and Cov_tau.")
#     217         try:
# --> 218             eigenvalues, eigenvectors = eig_corr(self.cov, self.cov_tau, self.epsilon, sign_maxelement=True)
#     219         except ZeroRankError:
#     220             raise ZeroRankError('All input features are constant in all time steps. No dimension would be left after dimension reduction.')
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/_ext/variational/solvers/direct.py in eig_corr(C0, Ct, epsilon, method, sign_maxelement)
#     270
#     271     """
# --> 272     L = spd_inv_split(C0, epsilon=epsilon, method=method, canonical_signs=True)
#     273     Ct_trans = _np.dot(_np.dot(L.T, Ct), L)
#     274
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/_ext/variational/solvers/direct.py in spd_inv_split(W, epsilon, method, canonical_signs)
#     217         L = 1./_np.sqrt(W[0,0])
#     218     else:
# --> 219         sm, Vm = spd_eig(W, epsilon=epsilon, method=method, canonical_signs=canonical_signs)
#     220         L = _np.dot(Vm, _np.diag(1.0/_np.sqrt(sm)))
#     221
#
# ~/Software/anaconda3/lib/python3.6/site-packages/pyemma/_ext/variational/solvers/direct.py in spd_eig(W, epsilon, method, canonical_signs)
#      67     if method.lower() == 'qr':
#      68         from .eig_qr.eig_qr import eig_qr
# ---> 69         s, V = eig_qr(W)
#      70     # compute the Eigenvalues of C0 using Schur factorization
#      71     elif method.lower() == 'schur':
#
# pyemma/_ext/variational/solvers/eig_qr/eig_qr.pyx in pyemma._ext.variational.solvers.eig_qr.eig_qr.eig_qr()
#
# ~/Software/anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py in require(a, dtype, requirements)
#     658
#     659
# --> 660 def require(a, dtype=None, requirements=None):
#     661     """
#     662     Return an ndarray of the provided type that satisfies requirements.
#
# KeyboardInterrupt:

# %%
tica_obj.cumvar
# Out:
# array([ 0.70874354,  1.        ])

# %%
Y = tica_obj.get_output()

# %%
t = md.load(trajfile, top=topfile, stride=100)
t
# Out:
# <mdtraj.Trajectory with 3964 frames, 2808 atoms, 192 residues, and unitcells at 0x7fab117495f8>

# %%
mpx_wdg_box = molpx.visualize.FES(t,
                                 #MD_trajfiles,
                                 t.topology,
                                 Y,
                                 #Y,
                                 nbins=50,
                                 #proj_idxs=[1,2],
                                 proj_labels='TIC',
                                 #n_overlays=5,
                                )
mpx_wdg_box
# Out:
# MolPXHBox(children=(NGLWidget(count=95), FigureCanvasNbAgg()))

# %%
matplotlib.rcParams.update({'font.size': 14})
dt = 0.01
plt.figure(figsize=(10, 10))
ax1=plt.subplot(211)
x = dt*np.arange(Y[0].shape[0])
plt.plot(x, Y[0][:, 0], linestyle='None', marker='o', markersize=.2); plt.ylabel('IC 1'); plt.xticks([]);
ax1=plt.subplot(212)
plt.plot(x, Y[0][:, 1], linestyle='None', marker='o', markersize=.2); plt.ylabel('IC 2'); plt.xticks([]);
# Out:
# FigureCanvasNbAgg()

# %%
matplotlib.rcParams.update({'font.size': 14})
dt = 0.01
plt.figure(figsize=(10, 10))
ax1=plt.subplot(211)
x = dt*np.arange(Y[0].shape[0])
plt.plot(x, Y[0][:, 0], linestyle='None', marker='o', markersize=.2); plt.ylabel('IC 1'); plt.xticks([]); plt.yticks(np.arange(-4, 4, 1))
ax1=plt.subplot(212)
plt.plot(x, Y[0][:, 1], linestyle='None', marker='o', markersize=.2); plt.ylabel('IC 2'); plt.xticks([]);  plt.yticks(np.arange(-4, 4, 1))
plt.show()
# Out:
# FigureCanvasNbAgg()
