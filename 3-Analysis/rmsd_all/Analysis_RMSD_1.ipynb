# %%
from collections import OrderedDict

import os
import sys
import glob
from itertools import cycle

import numpy as np
import pandas as pd

from os.path import join

import matplotlib 
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker

from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

import seaborn as sns
sns.set()

from os.path import join

print("Python version:\n{}\n".format(sys.version))
print("matplotlib version: {}".format(matplotlib.__version__))
print("pandas version: {}".format(pd.__version__))
print("numpy version: {}".format(np.__version__))
print("seaborn version: {}".format(sns.__version__))
# Out:
# Python version:
# 3.6.5 |Anaconda custom (64-bit)| (default, Apr 29 2018, 16:14:56)
# [GCC 7.2.0]
#
# matplotlib version: 2.2.2
# pandas version: 0.23.0
# numpy version: 1.12.1
# seaborn version: 0.8.1

# %%
sns.set(context='paper', style='whitegrid', font='sans-serif',\
        font_scale=1.6, rc={'grid.linestyle': '--'})

# %%
root_path = '..'
directories = ['1-Open/2-MD1']
starts= ['open']
basenames = ['rmsd_to_open_', 'rmsd_to_closed_']
extension = '.dat'

runs = ['1','2','3','4','5']  

dfs = OrderedDict()  # Mapping of system name to list of state DataFrames
rmsd_files = []

for directory in directories:
    for start in starts:
        for basename in basenames:
            for run in runs:
                filestring=start+'_'+basename+run+extension
                file_glob = os.path.join(root_path, directory, filestring)
                files = glob.glob(file_glob)
                for f in files:
                    # Read each into a file to be put into a dict
                    df = pd.read_csv(f, sep=r'\s+', skiprows=1, names=['frame', r'RMSD ($\AA$)'])
                    df[r'Time ($\mu$s)']=df['frame']*50/1000000
                    df['Run'] = int('{0}'.format(run))
                    df['Reference']=basename.strip('_')
                    df['Type']=start
                    df['Type_run']=start+'_'+run
                    rmsd_files.append(df)
df_all1=pd.concat(rmsd_files)
df_all1
# Out:
#        frame  RMSD ($\AA$)  Time ($\mu$s)  Run       Reference  Type Type_run
# 0          1        1.0089        0.00005    1    rmsd_to_open  open   open_1
# 1          2        0.9707        0.00010    1    rmsd_to_open  open   open_1
# 2          3        0.9916        0.00015    1    rmsd_to_open  open   open_1
# 3          4        1.1117        0.00020    1    rmsd_to_open  open   open_1
# 4          5        1.2100        0.00025    1    rmsd_to_open  open   open_1
# 5          6        0.9842        0.00030    1    rmsd_to_open  open   open_1
# 6          7        0.9748        0.00035    1    rmsd_to_open  open   open_1
# 7          8        1.0515        0.00040    1    rmsd_to_open  open   open_1
# 8          9        1.1225        0.00045    1    rmsd_to_open  open   open_1
# 9         10        1.0064        0.00050    1    rmsd_to_open  open   open_1
# 10        11        0.9794        0.00055    1    rmsd_to_open  open   open_1
# 11        12        0.9988        0.00060    1    rmsd_to_open  open   open_1
# 12        13        1.1310        0.00065    1    rmsd_to_open  open   open_1
# 13        14        1.0254        0.00070    1    rmsd_to_open  open   open_1
# 14        15        0.9528        0.00075    1    rmsd_to_open  open   open_1
# 15        16        0.9805        0.00080    1    rmsd_to_open  open   open_1
# 16        17        1.1580        0.00085    1    rmsd_to_open  open   open_1
# 17        18        1.1933        0.00090    1    rmsd_to_open  open   open_1
# 18        19        1.1626        0.00095    1    rmsd_to_open  open   open_1
# 19        20        1.2002        0.00100    1    rmsd_to_open  open   open_1
# 20        21        1.4090        0.00105    1    rmsd_to_open  open   open_1
# 21        22        1.6004        0.00110    1    rmsd_to_open  open   open_1
# 22        23        1.5012        0.00115    1    rmsd_to_open  open   open_1
# 23        24        1.4071        0.00120    1    rmsd_to_open  open   open_1
# 24        25        1.4105        0.00125    1    rmsd_to_open  open   open_1
# 25        26        1.3945        0.00130    1    rmsd_to_open  open   open_1
# 26        27        1.3843        0.00135    1    rmsd_to_open  open   open_1
# 27        28        1.3284        0.00140    1    rmsd_to_open  open   open_1
# 28        29        1.3788        0.00145    1    rmsd_to_open  open   open_1
# 29        30        1.2681        0.00150    1    rmsd_to_open  open   open_1
# ...      ...           ...            ...  ...             ...   ...      ...
# 40170  40171        3.0689        2.00855    5  rmsd_to_closed  open   open_5
# 40171  40172        3.1765        2.00860    5  rmsd_to_closed  open   open_5
# 40172  40173        3.0108        2.00865    5  rmsd_to_closed  open   open_5
# 40173  40174        3.1064        2.00870    5  rmsd_to_closed  open   open_5
# 40174  40175        3.1307        2.00875    5  rmsd_to_closed  open   open_5
# 40175  40176        2.9778        2.00880    5  rmsd_to_closed  open   open_5
# 40176  40177        2.8666        2.00885    5  rmsd_to_closed  open   open_5
# 40177  40178        2.9542        2.00890    5  rmsd_to_closed  open   open_5
# 40178  40179        3.0297        2.00895    5  rmsd_to_closed  open   open_5
# 40179  40180        2.9066        2.00900    5  rmsd_to_closed  open   open_5
# 40180  40181        2.8730        2.00905    5  rmsd_to_closed  open   open_5
# 40181  40182        3.1209        2.00910    5  rmsd_to_closed  open   open_5
# 40182  40183        2.9819        2.00915    5  rmsd_to_closed  open   open_5
# 40183  40184        2.7720        2.00920    5  rmsd_to_closed  open   open_5
# 40184  40185        3.0095        2.00925    5  rmsd_to_closed  open   open_5
# 40185  40186        3.0458        2.00930    5  rmsd_to_closed  open   open_5
# 40186  40187        2.9935        2.00935    5  rmsd_to_closed  open   open_5
# 40187  40188        3.0020        2.00940    5  rmsd_to_closed  open   open_5
# 40188  40189        2.8112        2.00945    5  rmsd_to_closed  open   open_5
# 40189  40190        2.7896        2.00950    5  rmsd_to_closed  open   open_5
# 40190  40191        2.7257        2.00955    5  rmsd_to_closed  open   open_5
# 40191  40192        2.8323        2.00960    5  rmsd_to_closed  open   open_5
# 40192  40193        2.9104        2.00965    5  rmsd_to_closed  open   open_5
# 40193  40194        2.8965        2.00970    5  rmsd_to_closed  open   open_5
# 40194  40195        2.9160        2.00975    5  rmsd_to_closed  open   open_5
# 40195  40196        3.0739        2.00980    5  rmsd_to_closed  open   open_5
# 40196  40197        2.9337        2.00985    5  rmsd_to_closed  open   open_5
# 40197  40198        2.9313        2.00990    5  rmsd_to_closed  open   open_5
# 40198  40199        3.0048        2.00995    5  rmsd_to_closed  open   open_5
# 40199  40200        2.9000        2.01000    5  rmsd_to_closed  open   open_5
#
# [396840 rows x 7 columns]

# %%
grid = sns.FacetGrid(df_all1, col="Run", col_wrap=3, hue="Reference", size=5, aspect=1.25,\
                     sharex=False, sharey=False, despine=False, legend_out=False)
grid = grid.map(plt.plot, r'Time ($\mu$s)', r'RMSD ($\AA$)').set_titles("Open - Run {col_name}")
#grid.map(plt.axvline, x=0.01, ls="-") 
grid.set(xlim=(0, 2.01) , ylim=(0, 6))
plt.legend()

plt.savefig('./open_rmsd.png')
plt.savefig('./open_rmsd.pdf')
plt.show()
# Out:
# /home/el14718/Software/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
root_path = '..'
directories = ['2-Closed/2-MD1']
starts= ['closed']
basenames = ['rmsd_to_open_', 'rmsd_to_closed_']
extension = '.dat'

runs = ['1','2','3','4','5']  

dfs = OrderedDict()  # Mapping of system name to list of state DataFrames
rmsd_files = []

for directory in directories:
    for start in starts:
        for basename in basenames:
            for run in runs:
                filestring=start+'_'+basename+run+extension
                file_glob = os.path.join(root_path, directory, filestring)
                files = glob.glob(file_glob)
                for f in files:
                    # Read each into a file to be put into a dict
                    df = pd.read_csv(f, sep=r'\s+', skiprows=1, names=['frame', r'RMSD ($\AA$)'])
                    df[r'Time ($\mu$s)']=df['frame']*50/1000000
                    df['Run'] = int('{0}'.format(run))
                    df['Reference']=basename.strip('_')
                    df['Type']=start
                    df['Type_run']=start+'_'+run
                    rmsd_files.append(df)
df_all2=pd.concat(rmsd_files)
df_all2
# Out:
#        frame  RMSD ($\AA$)  Time ($\mu$s)  Run       Reference    Type  \
# 0          1        3.1327        0.00005    1    rmsd_to_open  closed
# 1          2        3.3215        0.00010    1    rmsd_to_open  closed
# 2          3        2.9228        0.00015    1    rmsd_to_open  closed
# 3          4        3.1992        0.00020    1    rmsd_to_open  closed
# 4          5        2.9789        0.00025    1    rmsd_to_open  closed
# 5          6        2.8584        0.00030    1    rmsd_to_open  closed
# 6          7        2.8680        0.00035    1    rmsd_to_open  closed
# 7          8        2.8159        0.00040    1    rmsd_to_open  closed
# 8          9        2.7652        0.00045    1    rmsd_to_open  closed
# 9         10        2.9834        0.00050    1    rmsd_to_open  closed
# 10        11        2.9383        0.00055    1    rmsd_to_open  closed
# 11        12        2.8548        0.00060    1    rmsd_to_open  closed
# 12        13        3.0036        0.00065    1    rmsd_to_open  closed
# 13        14        2.8723        0.00070    1    rmsd_to_open  closed
# 14        15        2.9072        0.00075    1    rmsd_to_open  closed
# 15        16        2.8885        0.00080    1    rmsd_to_open  closed
# 16        17        2.9071        0.00085    1    rmsd_to_open  closed
# 17        18        2.8476        0.00090    1    rmsd_to_open  closed
# 18        19        2.9870        0.00095    1    rmsd_to_open  closed
# 19        20        2.8117        0.00100    1    rmsd_to_open  closed
# 20        21        2.8830        0.00105    1    rmsd_to_open  closed
# 21        22        2.8707        0.00110    1    rmsd_to_open  closed
# 22        23        2.9576        0.00115    1    rmsd_to_open  closed
# 23        24        2.9283        0.00120    1    rmsd_to_open  closed
# 24        25        2.9704        0.00125    1    rmsd_to_open  closed
# 25        26        2.9660        0.00130    1    rmsd_to_open  closed
# 26        27        2.9899        0.00135    1    rmsd_to_open  closed
# 27        28        2.9618        0.00140    1    rmsd_to_open  closed
# 28        29        2.8725        0.00145    1    rmsd_to_open  closed
# 29        30        2.7847        0.00150    1    rmsd_to_open  closed
# ...      ...           ...            ...  ...             ...     ...
# 40170  40171        2.9006        2.00855    5  rmsd_to_closed  closed
# 40171  40172        3.0086        2.00860    5  rmsd_to_closed  closed
# 40172  40173        3.1203        2.00865    5  rmsd_to_closed  closed
# 40173  40174        2.9899        2.00870    5  rmsd_to_closed  closed
# 40174  40175        2.9664        2.00875    5  rmsd_to_closed  closed
# 40175  40176        3.0770        2.00880    5  rmsd_to_closed  closed
# 40176  40177        3.1692        2.00885    5  rmsd_to_closed  closed
# 40177  40178        2.9613        2.00890    5  rmsd_to_closed  closed
# 40178  40179        2.9103        2.00895    5  rmsd_to_closed  closed
# 40179  40180        3.0159        2.00900    5  rmsd_to_closed  closed
# 40180  40181        3.0378        2.00905    5  rmsd_to_closed  closed
# 40181  40182        3.0887        2.00910    5  rmsd_to_closed  closed
# 40182  40183        2.8778        2.00915    5  rmsd_to_closed  closed
# 40183  40184        3.0160        2.00920    5  rmsd_to_closed  closed
# 40184  40185        3.1274        2.00925    5  rmsd_to_closed  closed
# 40185  40186        3.0571        2.00930    5  rmsd_to_closed  closed
# 40186  40187        2.9584        2.00935    5  rmsd_to_closed  closed
# 40187  40188        2.9622        2.00940    5  rmsd_to_closed  closed
# 40188  40189        3.0091        2.00945    5  rmsd_to_closed  closed
# 40189  40190        2.8233        2.00950    5  rmsd_to_closed  closed
# 40190  40191        3.0462        2.00955    5  rmsd_to_closed  closed
# 40191  40192        3.1123        2.00960    5  rmsd_to_closed  closed
# 40192  40193        3.1854        2.00965    5  rmsd_to_closed  closed
# 40193  40194        2.9991        2.00970    5  rmsd_to_closed  closed
# 40194  40195        3.0442        2.00975    5  rmsd_to_closed  closed
# 40195  40196        2.9810        2.00980    5  rmsd_to_closed  closed
# 40196  40197        3.1583        2.00985    5  rmsd_to_closed  closed
# 40197  40198        2.8289        2.00990    5  rmsd_to_closed  closed
# 40198  40199        2.9988        2.00995    5  rmsd_to_closed  closed
# 40199  40200        3.0104        2.01000    5  rmsd_to_closed  closed
#
#        Type_run
# 0      closed_1
# 1      closed_1
# 2      closed_1
# 3      closed_1
# 4      closed_1
# 5      closed_1
# 6      closed_1
# 7      closed_1
# 8      closed_1
# 9      closed_1
# 10     closed_1
# 11     closed_1
# 12     closed_1
# 13     closed_1
# 14     closed_1
# 15     closed_1
# 16     closed_1
# 17     closed_1
# 18     closed_1
# 19     closed_1
# 20     closed_1
# 21     closed_1
# 22     closed_1
# 23     closed_1
# 24     closed_1
# 25     closed_1
# 26     closed_1
# 27     closed_1
# 28     closed_1
# 29     closed_1
# ...         ...
# 40170  closed_5
# 40171  closed_5
# 40172  closed_5
# 40173  closed_5
# 40174  closed_5
# 40175  closed_5
# 40176  closed_5
# 40177  closed_5
# 40178  closed_5
# 40179  closed_5
# 40180  closed_5
# 40181  closed_5
# 40182  closed_5
# 40183  closed_5
# 40184  closed_5
# 40185  closed_5
# 40186  closed_5
# 40187  closed_5
# 40188  closed_5
# 40189  closed_5
# 40190  closed_5
# 40191  closed_5
# 40192  closed_5
# 40193  closed_5
# 40194  closed_5
# 40195  closed_5
# 40196  closed_5
# 40197  closed_5
# 40198  closed_5
# 40199  closed_5
#
# [399782 rows x 7 columns]

# %%
grid = sns.FacetGrid(df_all2, col="Run", col_wrap=3, hue="Reference", size=5, aspect=1.25,\
                     sharex=False, sharey=False, despine=False, legend_out=False)
grid = grid.map(plt.plot, r'Time ($\mu$s)', r'RMSD ($\AA$)').set_titles("Closed - Run {col_name}")
grid.set(xlim=(0, 2.01) , ylim=(0, 4))
plt.legend()

plt.savefig('./closed_rmsd.png')
plt.savefig('./closed_rmsd.pdf')
plt.show()
# Out:
# /home/el14718/Software/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
root_path = '..'
directories = ['1-Open/2-MD1','2-Closed/2-MD1']
starts= ['closed', 'open']
basename = 'rmsd_to_open_'
extension = '.dat'

runs = ['1','2','3','4','5']  

dfs = OrderedDict()  # Mapping of system name to list of state DataFrames
rmsd_files = []

for directory in directories:
    for start in starts:
        for run in runs:
            filestring=start+'_'+basename+run+extension
            file_glob = os.path.join(root_path, directory, filestring)
            files = glob.glob(file_glob)
            for f in files:
                # Read each into a file to be put into a dict
                df = pd.read_csv(f, sep=r'\s+', skiprows=1, names=['frame', r'RMSD to Open ($\AA$)'])
                df[r'Time ($\mu$s)']=df['frame']*50/1000000
                df['Run'] = int('{0}'.format(run))
                df['Reference']=basename.strip('_')
                df['Type']=start
                df['Type_run']=start+'_'+run
                rmsd_files.append(df)
df1=pd.concat(rmsd_files)
df1
# Out:
#        frame  RMSD to Open ($\AA$)  Time ($\mu$s)  Run     Reference    Type  \
# 0          1                1.0089        0.00005    1  rmsd_to_open    open
# 1          2                0.9707        0.00010    1  rmsd_to_open    open
# 2          3                0.9916        0.00015    1  rmsd_to_open    open
# 3          4                1.1117        0.00020    1  rmsd_to_open    open
# 4          5                1.2100        0.00025    1  rmsd_to_open    open
# 5          6                0.9842        0.00030    1  rmsd_to_open    open
# 6          7                0.9748        0.00035    1  rmsd_to_open    open
# 7          8                1.0515        0.00040    1  rmsd_to_open    open
# 8          9                1.1225        0.00045    1  rmsd_to_open    open
# 9         10                1.0064        0.00050    1  rmsd_to_open    open
# 10        11                0.9794        0.00055    1  rmsd_to_open    open
# 11        12                0.9988        0.00060    1  rmsd_to_open    open
# 12        13                1.1310        0.00065    1  rmsd_to_open    open
# 13        14                1.0254        0.00070    1  rmsd_to_open    open
# 14        15                0.9528        0.00075    1  rmsd_to_open    open
# 15        16                0.9805        0.00080    1  rmsd_to_open    open
# 16        17                1.1580        0.00085    1  rmsd_to_open    open
# 17        18                1.1933        0.00090    1  rmsd_to_open    open
# 18        19                1.1626        0.00095    1  rmsd_to_open    open
# 19        20                1.2002        0.00100    1  rmsd_to_open    open
# 20        21                1.4090        0.00105    1  rmsd_to_open    open
# 21        22                1.6004        0.00110    1  rmsd_to_open    open
# 22        23                1.5012        0.00115    1  rmsd_to_open    open
# 23        24                1.4071        0.00120    1  rmsd_to_open    open
# 24        25                1.4105        0.00125    1  rmsd_to_open    open
# 25        26                1.3945        0.00130    1  rmsd_to_open    open
# 26        27                1.3843        0.00135    1  rmsd_to_open    open
# 27        28                1.3284        0.00140    1  rmsd_to_open    open
# 28        29                1.3788        0.00145    1  rmsd_to_open    open
# 29        30                1.2681        0.00150    1  rmsd_to_open    open
# ...      ...                   ...            ...  ...           ...     ...
# 40170  40171                2.3467        2.00855    5  rmsd_to_open  closed
# 40171  40172                2.4082        2.00860    5  rmsd_to_open  closed
# 40172  40173                2.4278        2.00865    5  rmsd_to_open  closed
# 40173  40174                2.2739        2.00870    5  rmsd_to_open  closed
# 40174  40175                2.4735        2.00875    5  rmsd_to_open  closed
# 40175  40176                2.4999        2.00880    5  rmsd_to_open  closed
# 40176  40177                2.5138        2.00885    5  rmsd_to_open  closed
# 40177  40178                2.5288        2.00890    5  rmsd_to_open  closed
# 40178  40179                2.5327        2.00895    5  rmsd_to_open  closed
# 40179  40180                2.4977        2.00900    5  rmsd_to_open  closed
# 40180  40181                2.5208        2.00905    5  rmsd_to_open  closed
# 40181  40182                2.5504        2.00910    5  rmsd_to_open  closed
# 40182  40183                2.3483        2.00915    5  rmsd_to_open  closed
# 40183  40184                2.5064        2.00920    5  rmsd_to_open  closed
# 40184  40185                2.5422        2.00925    5  rmsd_to_open  closed
# 40185  40186                2.4262        2.00930    5  rmsd_to_open  closed
# 40186  40187                2.4046        2.00935    5  rmsd_to_open  closed
# 40187  40188                2.3924        2.00940    5  rmsd_to_open  closed
# 40188  40189                2.4648        2.00945    5  rmsd_to_open  closed
# 40189  40190                2.3928        2.00950    5  rmsd_to_open  closed
# 40190  40191                2.4402        2.00955    5  rmsd_to_open  closed
# 40191  40192                2.4213        2.00960    5  rmsd_to_open  closed
# 40192  40193                2.4200        2.00965    5  rmsd_to_open  closed
# 40193  40194                2.4323        2.00970    5  rmsd_to_open  closed
# 40194  40195                2.4752        2.00975    5  rmsd_to_open  closed
# 40195  40196                2.4328        2.00980    5  rmsd_to_open  closed
# 40196  40197                2.4280        2.00985    5  rmsd_to_open  closed
# 40197  40198                2.4582        2.00990    5  rmsd_to_open  closed
# 40198  40199                2.4691        2.00995    5  rmsd_to_open  closed
# 40199  40200                2.5315        2.01000    5  rmsd_to_open  closed
#
#        Type_run
# 0        open_1
# 1        open_1
# 2        open_1
# 3        open_1
# 4        open_1
# 5        open_1
# 6        open_1
# 7        open_1
# 8        open_1
# 9        open_1
# 10       open_1
# 11       open_1
# 12       open_1
# 13       open_1
# 14       open_1
# 15       open_1
# 16       open_1
# 17       open_1
# 18       open_1
# 19       open_1
# 20       open_1
# 21       open_1
# 22       open_1
# 23       open_1
# 24       open_1
# 25       open_1
# 26       open_1
# 27       open_1
# 28       open_1
# 29       open_1
# ...         ...
# 40170  closed_5
# 40171  closed_5
# 40172  closed_5
# 40173  closed_5
# 40174  closed_5
# 40175  closed_5
# 40176  closed_5
# 40177  closed_5
# 40178  closed_5
# 40179  closed_5
# 40180  closed_5
# 40181  closed_5
# 40182  closed_5
# 40183  closed_5
# 40184  closed_5
# 40185  closed_5
# 40186  closed_5
# 40187  closed_5
# 40188  closed_5
# 40189  closed_5
# 40190  closed_5
# 40191  closed_5
# 40192  closed_5
# 40193  closed_5
# 40194  closed_5
# 40195  closed_5
# 40196  closed_5
# 40197  closed_5
# 40198  closed_5
# 40199  closed_5
#
# [398311 rows x 7 columns]

# %%
root_path = '..'
directories = ['1-Open/2-MD1','2-Closed/2-MD1']
starts= ['closed', 'open']
basename = 'rmsd_to_closed_'
extension = '.dat'

runs = ['1','2','3','4','5']  

dfs = OrderedDict()  # Mapping of system name to list of state DataFrames
rmsd_files = []

for directory in directories:
    for start in starts:
        for run in runs:
            filestring=start+'_'+basename+run+extension
            file_glob = os.path.join(root_path, directory, filestring)
            files = glob.glob(file_glob)
            for f in files:
                # Read each into a file to be put into a dict
                df = pd.read_csv(f, sep=r'\s+', skiprows=1, names=['frame', r'RMSD to Closed ($\AA$)'])
                df[r'Time ($\mu$s)']=df['frame']*50/1000000
                df['Run'] = int('{0}'.format(run))
                df['Reference']=basename.strip('_')
                df['Type']=start
                df['Type_run']=start+'_'+run
                rmsd_files.append(df)
df2=pd.concat(rmsd_files)
df2
# Out:
#        frame  RMSD to Closed ($\AA$)  Time ($\mu$s)  Run       Reference  \
# 0          1                  3.3276        0.00005    1  rmsd_to_closed
# 1          2                  3.2902        0.00010    1  rmsd_to_closed
# 2          3                  3.3135        0.00015    1  rmsd_to_closed
# 3          4                  3.4717        0.00020    1  rmsd_to_closed
# 4          5                  3.5352        0.00025    1  rmsd_to_closed
# 5          6                  3.4092        0.00030    1  rmsd_to_closed
# 6          7                  3.2720        0.00035    1  rmsd_to_closed
# 7          8                  3.4875        0.00040    1  rmsd_to_closed
# 8          9                  3.4158        0.00045    1  rmsd_to_closed
# 9         10                  3.1282        0.00050    1  rmsd_to_closed
# 10        11                  3.1856        0.00055    1  rmsd_to_closed
# 11        12                  3.2551        0.00060    1  rmsd_to_closed
# 12        13                  3.2781        0.00065    1  rmsd_to_closed
# 13        14                  3.3163        0.00070    1  rmsd_to_closed
# 14        15                  3.2970        0.00075    1  rmsd_to_closed
# 15        16                  3.4218        0.00080    1  rmsd_to_closed
# 16        17                  3.4799        0.00085    1  rmsd_to_closed
# 17        18                  3.4907        0.00090    1  rmsd_to_closed
# 18        19                  3.5122        0.00095    1  rmsd_to_closed
# 19        20                  3.4603        0.00100    1  rmsd_to_closed
# 20        21                  3.6078        0.00105    1  rmsd_to_closed
# 21        22                  3.6528        0.00110    1  rmsd_to_closed
# 22        23                  3.6364        0.00115    1  rmsd_to_closed
# 23        24                  3.7854        0.00120    1  rmsd_to_closed
# 24        25                  3.6644        0.00125    1  rmsd_to_closed
# 25        26                  3.5599        0.00130    1  rmsd_to_closed
# 26        27                  3.4938        0.00135    1  rmsd_to_closed
# 27        28                  3.4663        0.00140    1  rmsd_to_closed
# 28        29                  3.4960        0.00145    1  rmsd_to_closed
# 29        30                  3.2938        0.00150    1  rmsd_to_closed
# ...      ...                     ...            ...  ...             ...
# 40170  40171                  2.9006        2.00855    5  rmsd_to_closed
# 40171  40172                  3.0086        2.00860    5  rmsd_to_closed
# 40172  40173                  3.1203        2.00865    5  rmsd_to_closed
# 40173  40174                  2.9899        2.00870    5  rmsd_to_closed
# 40174  40175                  2.9664        2.00875    5  rmsd_to_closed
# 40175  40176                  3.0770        2.00880    5  rmsd_to_closed
# 40176  40177                  3.1692        2.00885    5  rmsd_to_closed
# 40177  40178                  2.9613        2.00890    5  rmsd_to_closed
# 40178  40179                  2.9103        2.00895    5  rmsd_to_closed
# 40179  40180                  3.0159        2.00900    5  rmsd_to_closed
# 40180  40181                  3.0378        2.00905    5  rmsd_to_closed
# 40181  40182                  3.0887        2.00910    5  rmsd_to_closed
# 40182  40183                  2.8778        2.00915    5  rmsd_to_closed
# 40183  40184                  3.0160        2.00920    5  rmsd_to_closed
# 40184  40185                  3.1274        2.00925    5  rmsd_to_closed
# 40185  40186                  3.0571        2.00930    5  rmsd_to_closed
# 40186  40187                  2.9584        2.00935    5  rmsd_to_closed
# 40187  40188                  2.9622        2.00940    5  rmsd_to_closed
# 40188  40189                  3.0091        2.00945    5  rmsd_to_closed
# 40189  40190                  2.8233        2.00950    5  rmsd_to_closed
# 40190  40191                  3.0462        2.00955    5  rmsd_to_closed
# 40191  40192                  3.1123        2.00960    5  rmsd_to_closed
# 40192  40193                  3.1854        2.00965    5  rmsd_to_closed
# 40193  40194                  2.9991        2.00970    5  rmsd_to_closed
# 40194  40195                  3.0442        2.00975    5  rmsd_to_closed
# 40195  40196                  2.9810        2.00980    5  rmsd_to_closed
# 40196  40197                  3.1583        2.00985    5  rmsd_to_closed
# 40197  40198                  2.8289        2.00990    5  rmsd_to_closed
# 40198  40199                  2.9988        2.00995    5  rmsd_to_closed
# 40199  40200                  3.0104        2.01000    5  rmsd_to_closed
#
#          Type  Type_run
# 0        open    open_1
# 1        open    open_1
# 2        open    open_1
# 3        open    open_1
# 4        open    open_1
# 5        open    open_1
# 6        open    open_1
# 7        open    open_1
# 8        open    open_1
# 9        open    open_1
# 10       open    open_1
# 11       open    open_1
# 12       open    open_1
# 13       open    open_1
# 14       open    open_1
# 15       open    open_1
# 16       open    open_1
# 17       open    open_1
# 18       open    open_1
# 19       open    open_1
# 20       open    open_1
# 21       open    open_1
# 22       open    open_1
# 23       open    open_1
# 24       open    open_1
# 25       open    open_1
# 26       open    open_1
# 27       open    open_1
# 28       open    open_1
# 29       open    open_1
# ...       ...       ...
# 40170  closed  closed_5
# 40171  closed  closed_5
# 40172  closed  closed_5
# 40173  closed  closed_5
# 40174  closed  closed_5
# 40175  closed  closed_5
# 40176  closed  closed_5
# 40177  closed  closed_5
# 40178  closed  closed_5
# 40179  closed  closed_5
# 40180  closed  closed_5
# 40181  closed  closed_5
# 40182  closed  closed_5
# 40183  closed  closed_5
# 40184  closed  closed_5
# 40185  closed  closed_5
# 40186  closed  closed_5
# 40187  closed  closed_5
# 40188  closed  closed_5
# 40189  closed  closed_5
# 40190  closed  closed_5
# 40191  closed  closed_5
# 40192  closed  closed_5
# 40193  closed  closed_5
# 40194  closed  closed_5
# 40195  closed  closed_5
# 40196  closed  closed_5
# 40197  closed  closed_5
# 40198  closed  closed_5
# 40199  closed  closed_5
#
# [398311 rows x 7 columns]

# %%
df_all = df1
df_all[r'RMSD to Closed ($\AA$)']=df2[r'RMSD to Closed ($\AA$)']
df_all
# Out:
#        frame  RMSD to Open ($\AA$)  Time ($\mu$s)  Run     Reference    Type  \
# 0          1                1.0089        0.00005    1  rmsd_to_open    open
# 1          2                0.9707        0.00010    1  rmsd_to_open    open
# 2          3                0.9916        0.00015    1  rmsd_to_open    open
# 3          4                1.1117        0.00020    1  rmsd_to_open    open
# 4          5                1.2100        0.00025    1  rmsd_to_open    open
# 5          6                0.9842        0.00030    1  rmsd_to_open    open
# 6          7                0.9748        0.00035    1  rmsd_to_open    open
# 7          8                1.0515        0.00040    1  rmsd_to_open    open
# 8          9                1.1225        0.00045    1  rmsd_to_open    open
# 9         10                1.0064        0.00050    1  rmsd_to_open    open
# 10        11                0.9794        0.00055    1  rmsd_to_open    open
# 11        12                0.9988        0.00060    1  rmsd_to_open    open
# 12        13                1.1310        0.00065    1  rmsd_to_open    open
# 13        14                1.0254        0.00070    1  rmsd_to_open    open
# 14        15                0.9528        0.00075    1  rmsd_to_open    open
# 15        16                0.9805        0.00080    1  rmsd_to_open    open
# 16        17                1.1580        0.00085    1  rmsd_to_open    open
# 17        18                1.1933        0.00090    1  rmsd_to_open    open
# 18        19                1.1626        0.00095    1  rmsd_to_open    open
# 19        20                1.2002        0.00100    1  rmsd_to_open    open
# 20        21                1.4090        0.00105    1  rmsd_to_open    open
# 21        22                1.6004        0.00110    1  rmsd_to_open    open
# 22        23                1.5012        0.00115    1  rmsd_to_open    open
# 23        24                1.4071        0.00120    1  rmsd_to_open    open
# 24        25                1.4105        0.00125    1  rmsd_to_open    open
# 25        26                1.3945        0.00130    1  rmsd_to_open    open
# 26        27                1.3843        0.00135    1  rmsd_to_open    open
# 27        28                1.3284        0.00140    1  rmsd_to_open    open
# 28        29                1.3788        0.00145    1  rmsd_to_open    open
# 29        30                1.2681        0.00150    1  rmsd_to_open    open
# ...      ...                   ...            ...  ...           ...     ...
# 40170  40171                2.3467        2.00855    5  rmsd_to_open  closed
# 40171  40172                2.4082        2.00860    5  rmsd_to_open  closed
# 40172  40173                2.4278        2.00865    5  rmsd_to_open  closed
# 40173  40174                2.2739        2.00870    5  rmsd_to_open  closed
# 40174  40175                2.4735        2.00875    5  rmsd_to_open  closed
# 40175  40176                2.4999        2.00880    5  rmsd_to_open  closed
# 40176  40177                2.5138        2.00885    5  rmsd_to_open  closed
# 40177  40178                2.5288        2.00890    5  rmsd_to_open  closed
# 40178  40179                2.5327        2.00895    5  rmsd_to_open  closed
# 40179  40180                2.4977        2.00900    5  rmsd_to_open  closed
# 40180  40181                2.5208        2.00905    5  rmsd_to_open  closed
# 40181  40182                2.5504        2.00910    5  rmsd_to_open  closed
# 40182  40183                2.3483        2.00915    5  rmsd_to_open  closed
# 40183  40184                2.5064        2.00920    5  rmsd_to_open  closed
# 40184  40185                2.5422        2.00925    5  rmsd_to_open  closed
# 40185  40186                2.4262        2.00930    5  rmsd_to_open  closed
# 40186  40187                2.4046        2.00935    5  rmsd_to_open  closed
# 40187  40188                2.3924        2.00940    5  rmsd_to_open  closed
# 40188  40189                2.4648        2.00945    5  rmsd_to_open  closed
# 40189  40190                2.3928        2.00950    5  rmsd_to_open  closed
# 40190  40191                2.4402        2.00955    5  rmsd_to_open  closed
# 40191  40192                2.4213        2.00960    5  rmsd_to_open  closed
# 40192  40193                2.4200        2.00965    5  rmsd_to_open  closed
# 40193  40194                2.4323        2.00970    5  rmsd_to_open  closed
# 40194  40195                2.4752        2.00975    5  rmsd_to_open  closed
# 40195  40196                2.4328        2.00980    5  rmsd_to_open  closed
# 40196  40197                2.4280        2.00985    5  rmsd_to_open  closed
# 40197  40198                2.4582        2.00990    5  rmsd_to_open  closed
# 40198  40199                2.4691        2.00995    5  rmsd_to_open  closed
# 40199  40200                2.5315        2.01000    5  rmsd_to_open  closed
#
#        Type_run  RMSD to Closed ($\AA$)
# 0        open_1                  3.3276
# 1        open_1                  3.2902
# 2        open_1                  3.3135
# 3        open_1                  3.4717
# 4        open_1                  3.5352
# 5        open_1                  3.4092
# 6        open_1                  3.2720
# 7        open_1                  3.4875
# 8        open_1                  3.4158
# 9        open_1                  3.1282
# 10       open_1                  3.1856
# 11       open_1                  3.2551
# 12       open_1                  3.2781
# 13       open_1                  3.3163
# 14       open_1                  3.2970
# 15       open_1                  3.4218
# 16       open_1                  3.4799
# 17       open_1                  3.4907
# 18       open_1                  3.5122
# 19       open_1                  3.4603
# 20       open_1                  3.6078
# 21       open_1                  3.6528
# 22       open_1                  3.6364
# 23       open_1                  3.7854
# 24       open_1                  3.6644
# 25       open_1                  3.5599
# 26       open_1                  3.4938
# 27       open_1                  3.4663
# 28       open_1                  3.4960
# 29       open_1                  3.2938
# ...         ...                     ...
# 40170  closed_5                  2.9006
# 40171  closed_5                  3.0086
# 40172  closed_5                  3.1203
# 40173  closed_5                  2.9899
# 40174  closed_5                  2.9664
# 40175  closed_5                  3.0770
# 40176  closed_5                  3.1692
# 40177  closed_5                  2.9613
# 40178  closed_5                  2.9103
# 40179  closed_5                  3.0159
# 40180  closed_5                  3.0378
# 40181  closed_5                  3.0887
# 40182  closed_5                  2.8778
# 40183  closed_5                  3.0160
# 40184  closed_5                  3.1274
# 40185  closed_5                  3.0571
# 40186  closed_5                  2.9584
# 40187  closed_5                  2.9622
# 40188  closed_5                  3.0091
# 40189  closed_5                  2.8233
# 40190  closed_5                  3.0462
# 40191  closed_5                  3.1123
# 40192  closed_5                  3.1854
# 40193  closed_5                  2.9991
# 40194  closed_5                  3.0442
# 40195  closed_5                  2.9810
# 40196  closed_5                  3.1583
# 40197  closed_5                  2.8289
# 40198  closed_5                  2.9988
# 40199  closed_5                  3.0104
#
# [398311 rows x 8 columns]

# %%
s1 = pd.Series([0.0,3.1458])
s2 = pd.Series([3.1458,0.0])
s3 = pd.Series(['open','closed'])
d={r'RMSD to Open ($\AA$)': s1, r'RMSD to Closed ($\AA$)': s2, 'Type':s3}
df_xray=pd.DataFrame(d)
df_xray
# Out:
#    RMSD to Open ($\AA$)  RMSD to Closed ($\AA$)    Type
# 0                0.0000                  3.1458    open
# 1                3.1458                  0.0000  closed

# %%
deep2=["#C44E52","#8172B2","#4C72B0",
       "#64B5CD", "#CCB974", "#55A868"]
palette=sns.color_palette(deep2)

sns.palplot(palette)
# Out:
# /home/el14718/Software/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
deep2=["#55A868", "#4C72B0","#55A868","#4C72B0",
        ]
palette=sns.color_palette(deep2)

sns.set(context='paper', style='whitegrid', palette=sns.color_palette(deep2), font='sans-serif',\
        font_scale=1.6, rc={'grid.linestyle': '--'})

fig, axes = plt.subplots(1)

df_all.groupby("Type").plot(x=r'RMSD to Closed ($\AA$)', y=r'RMSD to Open ($\AA$)',
                            ax=axes, marker=".", ms=2, ls='None', alpha=1)

df_xray.groupby("Type").plot(x=r'RMSD to Closed ($\AA$)', y=r'RMSD to Open ($\AA$)',
                            ax=axes, marker="s", ms=10, ls='None')


start, stop = axes.get_xlim()
loc = plticker.MultipleLocator(base=0.5)
axes.xaxis.set_major_locator(loc)
#axes.set_aspect('equal')
axes.set_xlabel(r'RMSD to closed ($\AA$)')
axes.set_ylabel(r'RMSD to open ($\AA$)')
axes.set(xlim=(0,6) , ylim=(0, 4))
axes.legend_.remove()


plt.savefig('./RMSD.pdf')
plt.savefig('./RMSD.png')
plt.show()
# Out:
# /home/el14718/Software/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
sns.set(context='paper', style='whitegrid', font='sans-serif',\
        font_scale=1.6, rc={'grid.linestyle': '--'})

grid = sns.FacetGrid(df_all, col="Type_run", col_wrap=3, hue="Type", size=5, aspect=1.25,\
                     sharex=False, sharey=False, despine=False, legend_out=False)
grid = grid.map(plt.plot, r'RMSD to Closed ($\AA$)', r'RMSD to Open ($\AA$)', 
                marker=".", ms=2, ls='None').set_titles("{col_name}")
grid.set(xlim=(0, 6) , ylim=(0, 4))
plt.savefig('./rmsd.png')
plt.savefig('./rmsd.pdf')
plt.show()
# Out:
# /home/el14718/Software/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
